# %% [markdown]
# ## 1. Installation (Python 3.9.13)

# %%
# !pip install tensorflow==2.8.0 tensorflow-gpu==2.8.0 numpy matplotlib keras opencv-python scikit-learn pandas
# Out:
# Collecting tensorflow==2.8.0
#   Using cached tensorflow-2.8.0-cp39-cp39-win_amd64.whl.metadata (2.9 kB)
# Collecting tensorflow-gpu==2.8.0
#   Using cached tensorflow_gpu-2.8.0-cp39-cp39-win_amd64.whl.metadata (2.9 kB)
# Collecting numpy
#   Using cached numpy-1.26.4-cp39-cp39-win_amd64.whl.metadata (61 kB)
# Collecting matplotlib
#   Using cached matplotlib-3.9.0-cp39-cp39-win_amd64.whl.metadata (11 kB)
# Collecting keras
#   Using cached keras-3.3.3-py3-none-any.whl.metadata (5.7 kB)
# Collecting opencv-python
#   Using cached opencv_python-4.9.0.80-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Collecting scikit-learn
#   Using cached scikit_learn-1.5.0-cp39-cp39-win_amd64.whl.metadata (11 kB)
# Collecting pandas
#   Using cached pandas-2.2.2-cp39-cp39-win_amd64.whl.metadata (19 kB)
# Collecting absl-py>=0.4.0 (from tensorflow==2.8.0)
#   Using cached absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow==2.8.0)
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=1.12 (from tensorflow==2.8.0)
#   Using cached flatbuffers-24.3.25-py2.py3-none-any.whl.metadata (850 bytes)
# Collecting gast>=0.2.1 (from tensorflow==2.8.0)
#   Using cached gast-0.5.4-py3-none-any.whl.metadata (1.3 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow==2.8.0)
#   Using cached google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting h5py>=2.9.0 (from tensorflow==2.8.0)
#   Using cached h5py-3.11.0-cp39-cp39-win_amd64.whl.metadata (2.5 kB)
# Collecting keras-preprocessing>=1.1.1 (from tensorflow==2.8.0)
#   Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl.metadata (1.9 kB)
# Collecting libclang>=9.0.1 (from tensorflow==2.8.0)
#   Using cached libclang-18.1.1-py2.py3-none-win_amd64.whl.metadata (5.3 kB)
# Collecting opt-einsum>=2.3.2 (from tensorflow==2.8.0)
#   Using cached opt_einsum-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting protobuf>=3.9.2 (from tensorflow==2.8.0)
#   Using cached protobuf-5.27.0-cp39-cp39-win_amd64.whl.metadata (592 bytes)
# Requirement already satisfied: setuptools in d:\kuliah\d4 - pens\proyek akhir\project\program\garbage\.venv\lib\site-packages (from tensorflow==2.8.0) (58.1.0)
# Requirement already satisfied: six>=1.12.0 in d:\kuliah\d4 - pens\proyek akhir\project\program\garbage\.venv\lib\site-packages (from tensorflow==2.8.0) (1.16.0)
# Collecting termcolor>=1.1.0 (from tensorflow==2.8.0)
#   Using cached termcolor-2.4.0-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in d:\kuliah\d4 - pens\proyek akhir\project\program\garbage\.venv\lib\site-packages (from tensorflow==2.8.0) (4.12.0)
# Collecting wrapt>=1.11.0 (from tensorflow==2.8.0)
#   Using cached wrapt-1.16.0-cp39-cp39-win_amd64.whl.metadata (6.8 kB)
# Collecting tensorboard<2.9,>=2.8 (from tensorflow==2.8.0)
#   Using cached tensorboard-2.8.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting tf-estimator-nightly==2.8.0.dev2021122109 (from tensorflow==2.8.0)
#   Using cached tf_estimator_nightly-2.8.0.dev2021122109-py2.py3-none-any.whl.metadata (1.2 kB)
# Collecting keras
#   Using cached keras-2.8.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1 (from tensorflow==2.8.0)
#   Using cached tensorflow_io_gcs_filesystem-0.31.0-cp39-cp39-win_amd64.whl.metadata (14 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow==2.8.0)
#   Using cached grpcio-1.64.0-cp39-cp39-win_amd64.whl.metadata (3.4 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.2.1-cp39-cp39-win_amd64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Using cached fonttools-4.52.4-cp39-cp39-win_amd64.whl.metadata (164 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Using cached kiwisolver-1.4.5-cp39-cp39-win_amd64.whl.metadata (6.5 kB)
# Requirement already satisfied: packaging>=20.0 in d:\kuliah\d4 - pens\proyek akhir\project\program\garbage\.venv\lib\site-packages (from matplotlib) (24.0)
# Collecting pillow>=8 (from matplotlib)
#   Using cached pillow-10.3.0-cp39-cp39-win_amd64.whl.metadata (9.4 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Using cached pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in d:\kuliah\d4 - pens\proyek akhir\project\program\garbage\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Collecting importlib-resources>=3.2.0 (from matplotlib)
#   Using cached importlib_resources-6.4.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting scipy>=1.6.0 (from scikit-learn)
#   Using cached scipy-1.13.1-cp39-cp39-win_amd64.whl.metadata (60 kB)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Using cached threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting wheel<1.0,>=0.23.0 (from astunparse>=1.6.0->tensorflow==2.8.0)
#   Using cached wheel-0.43.0-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: zipp>=3.1.0 in d:\kuliah\d4 - pens\proyek akhir\project\program\garbage\.venv\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.19.0)
# Collecting google-auth<3,>=1.6.3 (from tensorboard<2.9,>=2.8->tensorflow==2.8.0)
#   Using cached google_auth-2.29.0-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting google-auth-oauthlib<0.5,>=0.4.1 (from tensorboard<2.9,>=2.8->tensorflow==2.8.0)
#   Using cached google_auth_oauthlib-0.4.6-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting markdown>=2.6.8 (from tensorboard<2.9,>=2.8->tensorflow==2.8.0)
#   Using cached Markdown-3.6-py3-none-any.whl.metadata (7.0 kB)
# Collecting requests<3,>=2.21.0 (from tensorboard<2.9,>=2.8->tensorflow==2.8.0)
#   Using cached requests-2.32.2-py3-none-any.whl.metadata (4.6 kB)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0 (from tensorboard<2.9,>=2.8->tensorflow==2.8.0)
#   Using cached tensorboard_data_server-0.6.1-py3-none-any.whl.metadata (1.1 kB)
# Collecting tensorboard-plugin-wit>=1.6.0 (from tensorboard<2.9,>=2.8->tensorflow==2.8.0)
#   Using cached tensorboard_plugin_wit-1.8.1-py3-none-any.whl.metadata (873 bytes)
# Collecting werkzeug>=0.11.15 (from tensorboard<2.9,>=2.8->tensorflow==2.8.0)
#   Using cached werkzeug-3.0.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0)
#   Using cached cachetools-5.3.3-py3-none-any.whl.metadata (5.3 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0)
#   Using cached pyasn1_modules-0.4.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0)
#   Using cached rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8.0)
#   Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: importlib-metadata>=4.4 in d:\kuliah\d4 - pens\proyek akhir\project\program\garbage\.venv\lib\site-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (7.1.0)
# Collecting charset-normalizer<4,>=2 (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.0)
#   Using cached charset_normalizer-3.3.2-cp39-cp39-win_amd64.whl.metadata (34 kB)
# Collecting idna<4,>=2.5 (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.0)
#   Using cached idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.0)
#   Using cached urllib3-2.2.1-py3-none-any.whl.metadata (6.4 kB)
# Collecting certifi>=2017.4.17 (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.0)
#   Using cached certifi-2024.2.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting MarkupSafe>=2.1.1 (from werkzeug>=0.11.15->tensorboard<2.9,>=2.8->tensorflow==2.8.0)
#   Using cached MarkupSafe-2.1.5-cp39-cp39-win_amd64.whl.metadata (3.1 kB)
# Collecting pyasn1<0.7.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0)
#   Using cached pyasn1-0.6.0-py2.py3-none-any.whl.metadata (8.3 kB)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8.0)
#   Using cached oauthlib-3.2.2-py3-none-any.whl.metadata (7.5 kB)
# Using cached tensorflow-2.8.0-cp39-cp39-win_amd64.whl (438.0 MB)
# Using cached tensorflow_gpu-2.8.0-cp39-cp39-win_amd64.whl (438.0 MB)
# Using cached tf_estimator_nightly-2.8.0.dev2021122109-py2.py3-none-any.whl (462 kB)
# Using cached numpy-1.26.4-cp39-cp39-win_amd64.whl (15.8 MB)
# Using cached matplotlib-3.9.0-cp39-cp39-win_amd64.whl (7.9 MB)
# Using cached keras-2.8.0-py2.py3-none-any.whl (1.4 MB)
# Using cached opencv_python-4.9.0.80-cp37-abi3-win_amd64.whl (38.6 MB)
# Using cached scikit_learn-1.5.0-cp39-cp39-win_amd64.whl (11.0 MB)
# Using cached pandas-2.2.2-cp39-cp39-win_amd64.whl (11.6 MB)
# Using cached absl_py-2.1.0-py3-none-any.whl (133 kB)
# Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Using cached contourpy-1.2.1-cp39-cp39-win_amd64.whl (182 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached flatbuffers-24.3.25-py2.py3-none-any.whl (26 kB)
# Using cached fonttools-4.52.4-cp39-cp39-win_amd64.whl (2.2 MB)
# Using cached gast-0.5.4-py3-none-any.whl (19 kB)
# Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Using cached grpcio-1.64.0-cp39-cp39-win_amd64.whl (4.1 MB)
# Using cached h5py-3.11.0-cp39-cp39-win_amd64.whl (3.0 MB)
# Using cached importlib_resources-6.4.0-py3-none-any.whl (38 kB)
# Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Using cached kiwisolver-1.4.5-cp39-cp39-win_amd64.whl (56 kB)
# Using cached libclang-18.1.1-py2.py3-none-win_amd64.whl (26.4 MB)
# Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Using cached pillow-10.3.0-cp39-cp39-win_amd64.whl (2.5 MB)
# Using cached protobuf-5.27.0-cp39-cp39-win_amd64.whl (426 kB)
# Using cached pyparsing-3.1.2-py3-none-any.whl (103 kB)
# Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Using cached scipy-1.13.1-cp39-cp39-win_amd64.whl (46.2 MB)
# Using cached tensorboard-2.8.0-py3-none-any.whl (5.8 MB)
# Using cached tensorflow_io_gcs_filesystem-0.31.0-cp39-cp39-win_amd64.whl (1.5 MB)
# Using cached termcolor-2.4.0-py3-none-any.whl (7.7 kB)
# Using cached threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# Using cached wrapt-1.16.0-cp39-cp39-win_amd64.whl (37 kB)
# Using cached google_auth-2.29.0-py2.py3-none-any.whl (189 kB)
# Using cached google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Using cached Markdown-3.6-py3-none-any.whl (105 kB)
# Using cached requests-2.32.2-py3-none-any.whl (63 kB)
# Using cached tensorboard_data_server-0.6.1-py3-none-any.whl (2.4 kB)
# Using cached tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
# Using cached werkzeug-3.0.3-py3-none-any.whl (227 kB)
# Using cached wheel-0.43.0-py3-none-any.whl (65 kB)
# Using cached cachetools-5.3.3-py3-none-any.whl (9.3 kB)
# Using cached certifi-2024.2.2-py3-none-any.whl (163 kB)
# Using cached charset_normalizer-3.3.2-cp39-cp39-win_amd64.whl (100 kB)
# Using cached idna-3.7-py3-none-any.whl (66 kB)
# Using cached MarkupSafe-2.1.5-cp39-cp39-win_amd64.whl (17 kB)
# Using cached pyasn1_modules-0.4.0-py3-none-any.whl (181 kB)
# Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Using cached urllib3-2.2.1-py3-none-any.whl (121 kB)
# Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Using cached pyasn1-0.6.0-py2.py3-none-any.whl (85 kB)
# Installing collected packages: tf-estimator-nightly, tensorboard-plugin-wit, pytz, libclang, keras, flatbuffers, wrapt, wheel, urllib3, tzdata, threadpoolctl, termcolor, tensorflow-io-gcs-filesystem, tensorboard-data-server, pyparsing, pyasn1, protobuf, pillow, oauthlib, numpy, MarkupSafe, kiwisolver, joblib, importlib-resources, idna, grpcio, google-pasta, gast, fonttools, cycler, charset-normalizer, certifi, cachetools, absl-py, werkzeug, scipy, rsa, requests, pyasn1-modules, pandas, opt-einsum, opencv-python, markdown, keras-preprocessing, h5py, contourpy, astunparse, scikit-learn, requests-oauthlib, matplotlib, google-auth, google-auth-oauthlib, tensorboard, tensorflow-gpu, tensorflow
# Successfully installed MarkupSafe-2.1.5 absl-py-2.1.0 astunparse-1.6.3 cachetools-5.3.3 certifi-2024.2.2 charset-normalizer-3.3.2 contourpy-1.2.1 cycler-0.12.1 flatbuffers-24.3.25 fonttools-4.52.4 gast-0.5.4 google-auth-2.29.0 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.64.0 h5py-3.11.0 idna-3.7 importlib-resources-6.4.0 joblib-1.4.2 keras-2.8.0 keras-preprocessing-1.1.2 kiwisolver-1.4.5 libclang-18.1.1 markdown-3.6 matplotlib-3.9.0 numpy-1.26.4 oauthlib-3.2.2 opencv-python-4.9.0.80 opt-einsum-3.3.0 pandas-2.2.2 pillow-10.3.0 protobuf-5.27.0 pyasn1-0.6.0 pyasn1-modules-0.4.0 pyparsing-3.1.2 pytz-2024.1 requests-2.32.2 requests-oauthlib-2.0.0 rsa-4.9 scikit-learn-1.5.0 scipy-1.13.1 tensorboard-2.8.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.8.0 tensorflow-gpu-2.8.0 tensorflow-io-gcs-filesystem-0.31.0 termcolor-2.4.0 tf-estimator-nightly-2.8.0.dev2021122109 threadpoolctl-3.5.0 tzdata-2024.1 urllib3-2.2.1 werkzeug-3.0.3 wheel-0.43.0 wrapt-1.16.0

# %%
# !pip install protobuf==3.20
# Out:
# Collecting protobuf==3.20
#   Using cached protobuf-3.20.0-cp39-cp39-win_amd64.whl.metadata (699 bytes)
# Using cached protobuf-3.20.0-cp39-cp39-win_amd64.whl (904 kB)
# Installing collected packages: protobuf
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.27.0
#     Uninstalling protobuf-5.27.0:
#       Successfully uninstalled protobuf-5.27.0
# Successfully installed protobuf-3.20.0

# %%
# !pip list
# Out:
# Package                      Version
# ---------------------------- -------------------
# absl-py                      2.1.0
# asttokens                    2.4.1
# astunparse                   1.6.3
# cachetools                   5.3.3
# certifi                      2024.2.2
# charset-normalizer           3.3.2
# colorama                     0.4.6
# comm                         0.2.2
# contourpy                    1.2.1
# cycler                       0.12.1
# debugpy                      1.8.1
# decorator                    5.1.1
# exceptiongroup               1.2.1
# executing                    2.0.1
# filelock                     3.13.1
# flatbuffers                  24.3.25
# fonttools                    4.52.4
# fsspec                       2024.2.0
# gast                         0.5.4
# google-auth                  2.29.0
# google-auth-oauthlib         0.4.6
# google-pasta                 0.2.0
# grpcio                       1.64.0
# h5py                         3.11.0
# idna                         3.7
# importlib_metadata           7.1.0
# importlib_resources          6.4.0
# intel-openmp                 2021.4.0
# ipykernel                    6.29.4
# ipython                      8.18.1
# jedi                         0.19.1
# Jinja2                       3.1.3
# joblib                       1.4.2
# jupyter_client               8.6.2
# jupyter_core                 5.7.2
# keras                        2.8.0
# Keras-Preprocessing          1.1.2
# kiwisolver                   1.4.5
# libclang                     18.1.1
# Markdown                     3.6
# MarkupSafe                   2.1.5
# matplotlib                   3.9.0
# matplotlib-inline            0.1.7
# mkl                          2021.4.0
# mpmath                       1.3.0
# nest-asyncio                 1.6.0
# networkx                     3.2.1
# numpy                        1.26.4
# oauthlib                     3.2.2
# opencv-python                4.9.0.80
# opt-einsum                   3.3.0
# packaging                    24.0
# pandas                       2.2.2
# parso                        0.8.4
# pillow                       10.3.0
# pip                          24.0
# platformdirs                 4.2.2
# prompt_toolkit               3.0.45
# protobuf                     3.20.0
# psutil                       5.9.8
# pure-eval                    0.2.2
# pyasn1                       0.6.0
# pyasn1_modules               0.4.0
# Pygments                     2.18.0
# pyparsing                    3.1.2
# python-dateutil              2.9.0.post0
# pytz                         2024.1
# pywin32                      306
# pyzmq                        26.0.3
# requests                     2.32.2
# requests-oauthlib            2.0.0
# rsa                          4.9
# scikit-learn                 1.5.0
# scipy                        1.13.1
# setuptools                   58.1.0
# six                          1.16.0
# stack-data                   0.6.3
# sympy                        1.12
# tbb                          2021.11.0
# tensorboard                  2.8.0
# tensorboard-data-server      0.6.1
# tensorboard-plugin-wit       1.8.1
# tensorflow                   2.8.0
# tensorflow-gpu               2.8.0
# tensorflow-io-gcs-filesystem 0.31.0
# termcolor                    2.4.0
# tf-estimator-nightly         2.8.0.dev2021122109
# threadpoolctl                3.5.0
# torch                        2.3.0+cu118
# torchaudio                   2.3.0+cu118
# torchvision                  0.18.0+cu118
# tornado                      6.4
# traitlets                    5.14.3
# typing_extensions            4.12.0
# tzdata                       2024.1
# urllib3                      2.2.1
# wcwidth                      0.2.13
# Werkzeug                     3.0.3
# wheel                        0.43.0
# wrapt                        1.16.0
# zipp                         3.19.0

# %% [markdown]
# ### 1.1 Limit GPU Memory Growth

# %%
import os
import cv2
import tensorflow as tf
import numpy as np
from matplotlib import pyplot as plt

# %%
gpus = tf.config.experimental.list_physical_devices("GPU")

for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)

# %%
tf.config.list_physical_devices("GPU")
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## 2. Augmentation

# %% [markdown]
# ### 2.1 Albumentations Installation

# %%
# !pip install albumentations

# %%
# !pip install torch

# %% [markdown]
# ### 2.2 Setup Albumentations Transform

# %%
# import albumentations as alb
# from albumentations.pytorch import ToTensorV2

# %%
# augmentor = alb.Compose(
#     [
#         alb.Resize(width=128, height=128),
#         alb.HorizontalFlip(p=0.5),
#         alb.RandomBrightnessContrast(p=0.2),
#         alb.RandomGamma(p=0.2),
#         alb.RGBShift(p=0.2),
#         alb.VerticalFlip(p=0.5),
#     ],
# )

# %% [markdown]
# ### 2.3 Run Augmentation

# %%
# # Function to process a single image and its XML annotation
# def process_image(image_path):
#     # Load the image
#     image = cv2.imread(image_path)

#     for x in range(10):
#         # Apply the augmentation
#         augmented = augmentor(image=image)

#         augmented_image = augmented["image"]

#         # Save the augmented image and create a new XML file with the updated bounding boxes
#         augmented_image_path = image_path.replace("images", "augmented_images")
#         augmented_image_path = augmented_image_path.replace(".jpg", f"{x}.jpg")

#         os.makedirs(os.path.dirname(augmented_image_path), exist_ok=True)

#         cv2.imwrite(augmented_image_path, augmented_image)

# %%
# base_dir = "../Garbage/images"
# for root, dirs, files in os.walk(base_dir):
#     for file in files:
#         if file.endswith(".jpg"):
#             image_path = os.path.join(root, file)
#             process_image(image_path)

# %% [markdown]
# ## 3. Beginning of the Project

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
import cv2
from sklearn.model_selection import train_test_split
import pickle
import os
import pandas as pd
import random
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.layers import BatchNormalization

# %% [markdown]
# ### 3.1 Setup Parameters

# %%
path = "augmented_images"
label_file = "labels.csv"
batch_size_val = 32  # Number of images to process together during training.
steps_per_epoch_val = 2000  # Baris ini mendefinisikan variabel steps_per_epoch_val yang menentukan jumlah iterasi pelatihan per epoch. Nilai 2000 berarti model akan dilatih selama 2000 iterasi setiap epoch.
epochs_val = 100
image_dimensions = (72, 128, 3) # Dimensions of the input images (height, width, channels).
test_ratio = 0.2  # If 1000 images split will 200 for testing (Baris ini mendefinisikan variabel testRatio yang menentukan proporsi data yang akan digunakan sebagai set tes. Nilai 0.2 berarti 20% dari data akan digunakan sebagai set tes, dan 80% sisanya akan digunakan sebagai set training dan validation).
validation_ratio = 0.1  # If 1000 images 20% of remaining 800 will be 160 for validation.

# %% [markdown]
# ### 3.2 Reads Images from Class Directories

# %%
count = 0
images = []
class_no = []
my_list = os.listdir(path)
print("Total Classes Detected:", len(my_list))
no_of_classes = len(my_list)
print("Importing Classes.....")
for x in range(0, len(my_list)):
    my_pic_list = os.listdir(path + "/" + str(count))  # Get list of images in current class directory.

    # Loop through each image in the class directory.
    for y in my_pic_list:
        cur_img = cv2.imread(path + "/" + str(count) + "/" + y)  # Read the image.
        images.append(cur_img)  # Append the image to the images list.
        class_no.append(count)  # Append the class number to the class_no list.
    print(count, end=" ")
    count += 1
print(" ")
images = np.array(images)  # Convert images list to numpy array.
class_no = np.array(class_no)  # Convert class_no list to numpy array.
# Out:
# Total Classes Detected: 2
# Importing Classes.....
# 0 1

# %% [markdown]
# ### 3.3 Split Images into Train, Val, and Test

# %%
# Split the dataset into training and testing sets, with the specified test ratio.
X_train, X_test, y_train, y_test = train_test_split(
    images, class_no, test_size=test_ratio
)

# Further split the training set into training and validation sets, with the specified validation ratio.
X_train, X_validation, y_train, y_validation = train_test_split(
    X_train, y_train, test_size=validation_ratio
)

# Calculate the number of steps per epoch for training and validation datasets, based on the batch size.
steps_per_epoch_val = len(X_train) // batch_size_val
validation_steps = len(X_test) // batch_size_val

# X_train = Array of images to train.
# y_train = Corresponding class id.

# %% [markdown]
# ### 3.4 Prints the Shapes of the Datasets to Ensure Consistency in the Number of Images and Labels

# %%
# Print the shapes of the datasets to check if the number of images matches the number of labels for each dataset.
print("Data Shapes")
print("Train", end="")
print(X_train.shape, y_train.shape)
print("Validation", end="")
print(X_validation.shape, y_validation.shape)
print("Test", end="")
print(X_test.shape, y_test.shape)

# Assert statements to ensure consistency in the number of images and labels across datasets and that image dimensions are correct.
assert (
    X_train.shape[0] == y_train.shape[0]
), "The number of images is not equal to the number of labels in training set"
assert (
    X_validation.shape[0] == y_validation.shape[0]
), "The number of images is not equal to the number of labels in validation set"
assert (
    X_test.shape[0] == y_test.shape[0]
), "The number of images is not equal to the number of labels in test set"
assert X_train.shape[1:] == (
    image_dimensions
), " The dimensions of the training images are wrong"
assert X_validation.shape[1:] == (
    image_dimensions
), " The dimensions of the validation images are wrong"
assert X_test.shape[1:] == (
    image_dimensions
), " The dimensions of the test images are wrong"
# Out:
# Data Shapes
# Train(279, 72, 128, 3) (279,)
# Validation(31, 72, 128, 3) (31,)
# Test(78, 72, 128, 3) (78,)

# %% [markdown]
# ### 3.5 Read CSV File (Labels)

# %%
data = pd.read_csv(label_file)

# %% [markdown]
# ### 3.6 Display Images of All the Classes

# %%
num_of_samples = []
cols = 5
num_classes = no_of_classes
fig, axs = plt.subplots(nrows=num_classes, ncols=cols, figsize=(5, 2))
fig.tight_layout()
for i in range(cols):
    for j, row in data.iterrows():
        x_selected = X_train[y_train == j]
        axs[j][i].imshow(
            x_selected[random.randint(0, len(x_selected) - 1), :, :],
            cmap=plt.get_cmap("gray"),
        )
        axs[j][i].axis("off")
        if i == 2:
            axs[j][i].set_title(str(j) + " - " + row["Name"])
            num_of_samples.append(len(x_selected))

# %% [markdown]
# ### 3.7 Distribution of the Dataset

# %%
# Calculate the number of samples for each class using the class labels.
num_of_samples_all = [np.sum(class_no == i) for i in range(no_of_classes)]

# Display the distribution of all images.
print(num_of_samples_all)
plt.figure(figsize=(12, 4))
plt.bar(range(0, no_of_classes), num_of_samples_all)
plt.title("Distribution of All Images")
plt.xlabel("Class Number")
plt.ylabel("Number of Images")
plt.show()
# Out:
# [161, 227]

# %% [markdown]
# ### 3.8 Distribution of the Training Dataset

# %%
print(num_of_samples)
sum(num_of_samples)
plt.figure(figsize=(12, 4))
plt.bar(range(0, num_classes), num_of_samples)
plt.title("Distribution of the Training Dataset")
plt.xlabel("Class Number")
plt.ylabel("Number of Images")
plt.show()
# Out:
# [118, 161]

# %% [markdown]
# ### 3.9 Preprocessing the Images

# %%
# Convert the image to grayscale.
def grayscale(img):
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    return img


# Apply histogram equalization to standardize the lighting in the image.
def equalize(img):
    img = cv2.equalizeHist(img)
    return img


def preprocessing(img):
    img = grayscale(img)
    img = equalize(img)
    img = img / 255  # Menormalisasi nilai piksel menjadi rentang 0 hingga 1.
    return img


# Menerapkan fungsi preprocessing ke setiap gambar dalam set pelatihan, validasi, dan tes.
X_train = np.array(list(map(preprocessing, X_train)))
X_validation = np.array(list(map(preprocessing, X_validation)))
X_test = np.array(list(map(preprocessing, X_test)))

# %%
y_train = to_categorical(y_train, no_of_classes)
y_validation = to_categorical(y_validation, no_of_classes)
y_test = to_categorical(y_test, no_of_classes)

# %%
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], X_train.shape[2], 1)
X_validation = X_validation.reshape(
    X_validation.shape[0], X_validation.shape[1], X_validation.shape[2], 1
)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], X_test.shape[2], 1)

# %% [markdown]
# ### 3.10 CNN Model

# %%
# def myModel():
#     no_of_filters = 60
#     size_of_filter = (5, 5)  # The kernel size used for convolutional layers, which moves around the image to extract features.
#     size_of_filter2 = (3, 3)  # Another kernel size used for convolutional layers.
#     size_of_pool = (2, 2)  # The size of the pooling operation.
#     no_of_nodes = 500  # Number of nodes in the hidden layers of the neural network.

#     model = Sequential()
#     # Menambahkan lapisan konvolusi dengan aktivasi relu dan ukuran filter pertama.
#     model.add(
#         (
#             Conv2D(
#                 no_of_filters,
#                 size_of_filter,
#                 input_shape=(image_dimensions[0], image_dimensions[1], 1),
#                 activation="relu",
#             )
#         )
#     )
#     # Menambahkan lapisan konvolusi kedua dengan ukuran filter yang sama.
#     model.add((Conv2D(no_of_filters, size_of_filter, activation="relu")))
#     # Add a max pooling layer to downscale the feature maps.
#     model.add(MaxPooling2D(pool_size=size_of_pool))

#     # Menambahkan lapisan konvolusi ketiga dengan setengah jumlah filter.
#     model.add((Conv2D(no_of_filters // 2, size_of_filter2, activation="relu")))
#     # Menambahkan lapisan konvolusi keempat dengan setengah jumlah filter.
#     model.add((Conv2D(no_of_filters // 2, size_of_filter2, activation="relu")))
#     # Menambahkan lapisan pooling kedua.
#     model.add(MaxPooling2D(pool_size=size_of_pool))
#     # Menambahkan lapisan dropout untuk mengurangi overfitting.
#     model.add(Dropout(0.5))

#     # Flatten the output of the convolutional layers (menjadi vektor satu dimensi).
#     model.add(Flatten())
#     # Menambahkan dense hidden layer with ReLU activation dengan jumlah node yang ditentukan.
#     model.add(Dense(no_of_nodes, activation="relu"))
#     # Menambahkan lapisan dropout kedua.
#     model.add(Dropout(0.5))
#     # Menambahkan lapisan output akhir dengan jumlah node yang sama dengan jumlah kelas dan aktivasi softmax untuk klasifikasi multiclass.
#     model.add(Dense(no_of_classes, activation="softmax"))

#     # Compile the model with Adam optimizer, categorical crossentropy loss (untuk klasifikasi multiclass), and accuracy metric.
#     #
#     model.compile(
#         Adam(learning_rate=0.001), loss="categorical_crossentropy", metrics=["accuracy"]
#     )

#     return model

# %%
def myModel():
    no_of_filters = 64
    size_of_filter = (3, 3)
    size_of_filter2 = (3, 3)
    size_of_pool = (2, 2)
    no_of_nodes = 512

    model = Sequential()
    # Convolutional Layer 1
    model.add(
        Conv2D(
            no_of_filters,
            size_of_filter,
            input_shape=(image_dimensions[0], image_dimensions[1], 1),
            activation="relu",
        )
    )
    model.add(BatchNormalization())

    # Convolutional Layer 2
    model.add(Conv2D(no_of_filters, size_of_filter, activation="relu"))
    model.add(BatchNormalization())

    # MaxPooling dan Dropout untuk Layer Convolutional 1 dan 2
    model.add(MaxPooling2D(pool_size=size_of_pool))
    model.add(Dropout(0.3))

    # Convolutional Layer 3
    model.add(Conv2D(no_of_filters // 2, size_of_filter2, activation="relu"))
    model.add(BatchNormalization())

    # Convolutional Layer 4
    model.add(Conv2D(no_of_filters // 2, size_of_filter2, activation="relu"))
    model.add(BatchNormalization())

    # MaxPooling dan Dropout untuk Layer Convolutional 3 dan 4
    model.add(MaxPooling2D(pool_size=size_of_pool))
    model.add(Dropout(0.3))

    # Flatten Layer
    model.add(Flatten())

    # Dense Layer
    model.add(Dense(no_of_nodes, activation="relu"))
    model.add(Dropout(0.5))

    # Output Layer
    model.add(Dense(no_of_classes, activation="softmax"))

    model.compile(
        Adam(learning_rate=0.001), loss="categorical_crossentropy", metrics=["accuracy"]
    )
    return model

# %%
# Callback untuk menyimpan model dengan validasi terbaik selama pelatihan.
checkpoint = ModelCheckpoint(
    "people_garbage_with_preprocessing_model.h5",
    verbose=1,  # Verbosity mode. 0 = silent, 1 = progress bar, 2 = one line per epoch.
    save_best_only=True,  # Indicates that only the model with the best validation loss will be saved.
)

# Callback untuk menghentikan pelatihan lebih awal jika tidak ada peningkatan.
early_stopping = EarlyStopping(
    monitor="val_loss",
    patience=10,  # Defines the number of epochs to wait without improvement before stopping training.
    restore_best_weights=True,  # Indicates that the model weights from the last epoch with the best validation loss should be loaded before resuming training if the training is restarted.
)

# Callback to reduce the learning rate if there is no improvement.
reduce_lr = ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.5,
    patience=5,  # Defines the number of epochs to wait without improvement before reducing the learning rate.
    min_lr=0.00001,  # Batas bawah laju pembelajaran.
)

# %%
model = myModel()
print(model.summary())
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_8 (Conv2D)           (None, 70, 126, 64)       640
#
#  batch_normalization_8 (Batc  (None, 70, 126, 64)      256
#  hNormalization)
#
#  conv2d_9 (Conv2D)           (None, 68, 124, 64)       36928
#
#  batch_normalization_9 (Batc  (None, 68, 124, 64)      256
#  hNormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 34, 62, 64)       0
#  2D)
#
#  dropout_6 (Dropout)         (None, 34, 62, 64)        0
#
#  conv2d_10 (Conv2D)          (None, 32, 60, 32)        18464
#
#  batch_normalization_10 (Bat  (None, 32, 60, 32)       128
#  chNormalization)
#
#  conv2d_11 (Conv2D)          (None, 30, 58, 32)        9248
#
#  batch_normalization_11 (Bat  (None, 30, 58, 32)       128
#  chNormalization)
#
#  max_pooling2d_5 (MaxPooling  (None, 15, 29, 32)       0
#  2D)
#
#  dropout_7 (Dropout)         (None, 15, 29, 32)        0
#
#  flatten_2 (Flatten)         (None, 13920)             0
#
#  dense_4 (Dense)             (None, 512)               7127552
#
#  dropout_8 (Dropout)         (None, 512)               0
#
#  dense_5 (Dense)             (None, 2)                 1026
#
# =================================================================
# Total params: 7,194,626
# Trainable params: 7,194,242
# Non-trainable params: 384
# _________________________________________________________________
# None

# %%
history = model.fit(
    X_train,
    y_train,
    batch_size=batch_size_val,
    steps_per_epoch=steps_per_epoch_val,
    epochs=epochs_val,
    callbacks=[checkpoint, early_stopping, reduce_lr],
    validation_data=(X_validation, y_validation),
    shuffle=True,
)
# Out:
# Epoch 1/100
# 7/8 [=========================>....] - ETA: 0s - loss: 6.6183 - accuracy: 0.7366
# Epoch 1: val_loss improved from inf to 0.59873, saving model to people_garbage_with_preprocessing_model.h5
# 8/8 [==============================] - 1s 86ms/step - loss: 5.7910 - accuracy: 0.7695 - val_loss: 0.5987 - val_accuracy: 0.5161 - lr: 0.0010
# Epoch 2/100
# 7/8 [=========================>....] - ETA: 0s - loss: 0.2279 - accuracy: 0.9814
# Epoch 2: val_loss did not improve from 0.59873
# 8/8 [==============================] - 0s 39ms/step - loss: 0.1984 - accuracy: 0.9838 - val_loss: 0.6149 - val_accuracy: 0.5161 - lr: 0.0010
# Epoch 3/100
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 3: val_loss did not improve from 0.59873
# 8/8 [==============================] - 0s 38ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.6267 - val_accuracy: 0.5161 - lr: 0.0010
# Epoch 4/100
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 4: val_loss did not improve from 0.59873
# 8/8 [==============================] - 0s 38ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.6339 - val_accuracy: 0.5161 - lr: 0.0010
# Epoch 5/100
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 5: val_loss improved from 0.59873 to 0.47440, saving model to people_garbage_with_preprocessing_model.h5
# 8/8 [==============================] - 0s 60ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.4744 - val_accuracy: 0.5161 - lr: 0.0010
# Epoch 6/100
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 6: val_loss improved from 0.47440 to 0.34386, saving model to people_garbage_with_preprocessing_model.h5
# 8/8 [==============================] - 0s 62ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.3439 - val_accuracy: 0.8065 - lr: 0.0010
# Epoch 7/100
# 7/8 [=========================>....] - ETA: 0s - loss: 5.5446e-10 - accuracy: 1.0000
# Epoch 7: val_loss improved from 0.34386 to 0.27006, saving model to people_garbage_with_preprocessing_model.h5
# 8/8 [==============================] - 0s 62ms/step - loss: 4.8263e-10 - accuracy: 1.0000 - val_loss: 0.2701 - val_accuracy: 0.9677 - lr: 0.0010
# Epoch 8/100
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 8: val_loss improved from 0.27006 to 0.23054, saving model to people_garbage_with_preprocessing_model.h5
# 8/8 [==============================] - 0s 63ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.2305 - val_accuracy: 0.9677 - lr: 0.0010
# Epoch 9/100
# 7/8 [=========================>....] - ETA: 0s - loss: 2.8123e-05 - accuracy: 1.0000
# Epoch 9: val_loss improved from 0.23054 to 0.21525, saving model to people_garbage_with_preprocessing_model.h5
# 8/8 [==============================] - 0s 61ms/step - loss: 2.5505e-05 - accuracy: 1.0000 - val_loss: 0.2153 - val_accuracy: 0.9677 - lr: 0.0010
# Epoch 10/100
# 7/8 [=========================>....] - ETA: 0s - loss: 5.3218e-10 - accuracy: 1.0000
# Epoch 10: val_loss improved from 0.21525 to 0.19359, saving model to people_garbage_with_preprocessing_model.h5
# 8/8 [==============================] - 0s 66ms/step - loss: 4.6566e-10 - accuracy: 1.0000 - val_loss: 0.1936 - val_accuracy: 0.9677 - lr: 0.0010
# Epoch 11/100
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 11: val_loss improved from 0.19359 to 0.17111, saving model to people_garbage_with_preprocessing_model.h5
# 8/8 [==============================] - 0s 59ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.1711 - val_accuracy: 0.9677 - lr: 0.0010
# Epoch 12/100
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 12: val_loss improved from 0.17111 to 0.14523, saving model to people_garbage_with_preprocessing_model.h5
# 8/8 [==============================] - 0s 60ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.1452 - val_accuracy: 0.9677 - lr: 0.0010
# Epoch 13/100
# 7/8 [=========================>....] - ETA: 0s - loss: 7.0971e-08 - accuracy: 1.0000
# Epoch 13: val_loss improved from 0.14523 to 0.11468, saving model to people_garbage_with_preprocessing_model.h5
# 8/8 [==============================] - 0s 61ms/step - loss: 6.1776e-08 - accuracy: 1.0000 - val_loss: 0.1147 - val_accuracy: 0.9677 - lr: 0.0010
# Epoch 14/100
# 7/8 [=========================>....] - ETA: 0s - loss: 7.4449e-05 - accuracy: 1.0000
# Epoch 14: val_loss improved from 0.11468 to 0.08534, saving model to people_garbage_with_preprocessing_model.h5
# 8/8 [==============================] - 0s 58ms/step - loss: 6.4804e-05 - accuracy: 1.0000 - val_loss: 0.0853 - val_accuracy: 0.9677 - lr: 0.0010
# Epoch 15/100
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 15: val_loss improved from 0.08534 to 0.05778, saving model to people_garbage_with_preprocessing_model.h5
# 8/8 [==============================] - 0s 58ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0578 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 16/100
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 16: val_loss improved from 0.05778 to 0.03434, saving model to people_garbage_with_preprocessing_model.h5
# 8/8 [==============================] - 0s 62ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0343 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 17/100
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 17: val_loss improved from 0.03434 to 0.01907, saving model to people_garbage_with_preprocessing_model.h5
# 8/8 [==============================] - 0s 58ms/step - loss: 1.9449e-07 - accuracy: 1.0000 - val_loss: 0.0191 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 18/100
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 18: val_loss improved from 0.01907 to 0.00972, saving model to people_garbage_with_preprocessing_model.h5
# 8/8 [==============================] - 0s 58ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0097 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 19/100
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 19: val_loss improved from 0.00972 to 0.00462, saving model to people_garbage_with_preprocessing_model.h5
# 8/8 [==============================] - 0s 64ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 20/100
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 20: val_loss improved from 0.00462 to 0.00204, saving model to people_garbage_with_preprocessing_model.h5
# 8/8 [==============================] - 0s 64ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 21/100
# 7/8 [=========================>....] - ETA: 0s - loss: 7.5293e-05 - accuracy: 1.0000
# Epoch 21: val_loss improved from 0.00204 to 0.00099, saving model to people_garbage_with_preprocessing_model.h5
# 8/8 [==============================] - 0s 58ms/step - loss: 6.5539e-05 - accuracy: 1.0000 - val_loss: 9.9352e-04 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 22/100
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 22: val_loss improved from 0.00099 to 0.00042, saving model to people_garbage_with_preprocessing_model.h5
# 8/8 [==============================] - 1s 72ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4.2283e-04 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 23/100
# 7/8 [=========================>....] - ETA: 0s - loss: 3.3822e-08 - accuracy: 1.0000
# Epoch 23: val_loss improved from 0.00042 to 0.00017, saving model to people_garbage_with_preprocessing_model.h5
# 8/8 [==============================] - 0s 58ms/step - loss: 2.9440e-08 - accuracy: 1.0000 - val_loss: 1.7122e-04 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 24/100
# 7/8 [=========================>....] - ETA: 0s - loss: 5.5446e-10 - accuracy: 1.0000
# Epoch 24: val_loss improved from 0.00017 to 0.00006, saving model to people_garbage_with_preprocessing_model.h5
# 8/8 [==============================] - 0s 61ms/step - loss: 4.8263e-10 - accuracy: 1.0000 - val_loss: 6.3906e-05 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 25/100
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 25: val_loss improved from 0.00006 to 0.00002, saving model to people_garbage_with_preprocessing_model.h5
# 8/8 [==============================] - 0s 60ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.4562e-05 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 26/100
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 26: val_loss improved from 0.00002 to 0.00001, saving model to people_garbage_with_preprocessing_model.h5
# 8/8 [==============================] - 0s 59ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.8979e-06 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 27/100
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 27: val_loss improved from 0.00001 to 0.00000, saving model to people_garbage_with_preprocessing_model.h5
# 8/8 [==============================] - 0s 66ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4.6030e-06 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 28/100
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 28: val_loss improved from 0.00000 to 0.00000, saving model to people_garbage_with_preprocessing_model.h5
# 8/8 [==============================] - 0s 61ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.6034e-06 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 29/100
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 29: val_loss improved from 0.00000 to 0.00000, saving model to people_garbage_with_preprocessing_model.h5
# 8/8 [==============================] - 0s 60ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 1.6920e-06 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 30/100
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 30: val_loss improved from 0.00000 to 0.00000, saving model to people_garbage_with_preprocessing_model.h5
# 8/8 [==============================] - 0s 66ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 1.1806e-06 - val_accuracy: 1.0000 - lr: 5.0000e-04
# Epoch 31/100
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 31: val_loss improved from 0.00000 to 0.00000, saving model to people_garbage_with_preprocessing_model.h5
# 8/8 [==============================] - 0s 58ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 7.9216e-07 - val_accuracy: 1.0000 - lr: 5.0000e-04
# Epoch 32/100
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 32: val_loss improved from 0.00000 to 0.00000, saving model to people_garbage_with_preprocessing_model.h5
# 8/8 [==============================] - 0s 58ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 5.1145e-07 - val_accuracy: 1.0000 - lr: 5.0000e-04
# Epoch 33/100
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 33: val_loss improved from 0.00000 to 0.00000, saving model to people_garbage_with_preprocessing_model.h5
# 8/8 [==============================] - 0s 61ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 3.1917e-07 - val_accuracy: 1.0000 - lr: 5.0000e-04
# Epoch 34/100
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 34: val_loss improved from 0.00000 to 0.00000, saving model to people_garbage_with_preprocessing_model.h5
# 8/8 [==============================] - 0s 61ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 1.9612e-07 - val_accuracy: 1.0000 - lr: 5.0000e-04
# Epoch 35/100
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 35: val_loss improved from 0.00000 to 0.00000, saving model to people_garbage_with_preprocessing_model.h5
# 8/8 [==============================] - 0s 59ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 1.1152e-07 - val_accuracy: 1.0000 - lr: 2.5000e-04
# Epoch 36/100
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 36: val_loss improved from 0.00000 to 0.00000, saving model to people_garbage_with_preprocessing_model.h5
# 8/8 [==============================] - 0s 58ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 5.7682e-08 - val_accuracy: 1.0000 - lr: 2.5000e-04
# Epoch 37/100
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 37: val_loss improved from 0.00000 to 0.00000, saving model to people_garbage_with_preprocessing_model.h5
# 8/8 [==============================] - 0s 65ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.3073e-08 - val_accuracy: 1.0000 - lr: 2.5000e-04
# Epoch 38/100
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 38: val_loss improved from 0.00000 to 0.00000, saving model to people_garbage_with_preprocessing_model.h5
# 8/8 [==============================] - 0s 58ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 7.6909e-09 - val_accuracy: 1.0000 - lr: 2.5000e-04
# Epoch 39/100
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 39: val_loss improved from 0.00000 to 0.00000, saving model to people_garbage_with_preprocessing_model.h5
# 8/8 [==============================] - 0s 60ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 3.8455e-09 - val_accuracy: 1.0000 - lr: 2.5000e-04
# Epoch 40/100
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 40: val_loss improved from 0.00000 to 0.00000, saving model to people_garbage_with_preprocessing_model.h5
# 8/8 [==============================] - 0s 61ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.2500e-04
# Epoch 41/100
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 41: val_loss did not improve from 0.00000
# 8/8 [==============================] - 0s 39ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.2500e-04
# Epoch 42/100
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 42: val_loss did not improve from 0.00000
# 8/8 [==============================] - 0s 37ms/step - loss: 1.2989e-04 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.2500e-04
# Epoch 43/100
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 43: val_loss did not improve from 0.00000
# 8/8 [==============================] - 0s 37ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.2500e-04
# Epoch 44/100
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 44: val_loss did not improve from 0.00000
# 8/8 [==============================] - 0s 38ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.2500e-04
# Epoch 45/100
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 45: val_loss did not improve from 0.00000
# 8/8 [==============================] - 0s 38ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 6.2500e-05
# Epoch 46/100
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 46: val_loss did not improve from 0.00000
# 8/8 [==============================] - 0s 40ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 6.2500e-05
# Epoch 47/100
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 47: val_loss did not improve from 0.00000
# 8/8 [==============================] - 0s 39ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 6.2500e-05
# Epoch 48/100
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 48: val_loss did not improve from 0.00000
# 8/8 [==============================] - 0s 38ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 6.2500e-05
# Epoch 49/100
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 49: val_loss did not improve from 0.00000
# 8/8 [==============================] - 0s 38ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 6.2500e-05
# Epoch 50/100
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 50: val_loss did not improve from 0.00000
# 8/8 [==============================] - 0s 39ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 3.1250e-05

# %% [markdown]
# ### 3.11 Evaluating the Model

# %%
plt.figure(1)
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.legend(["Training", "Validation"])
plt.title("Loss")
plt.xlabel("Epoch")

plt.figure(2)
plt.plot(history.history["accuracy"])
plt.plot(history.history["val_accuracy"])
plt.legend(["Training", "Validation"])
plt.title("Accuracy")
plt.xlabel("Epoch")
plt.show()

score = model.evaluate(X_test, y_test, verbose=0)
print("Test Score:", score[0])
print("Test Accuracy:", score[1])
# Out:
# Test Score: 0.0
# Test Accuracy: 1.0

# %% [markdown]
# Confusion Matrix

# %%
# !pip install seaborn
# Out:
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in d:\kuliah\d4 - pens\proyek akhir\project\program\garbage\.venv\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in d:\kuliah\d4 - pens\proyek akhir\project\program\garbage\.venv\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in d:\kuliah\d4 - pens\proyek akhir\project\program\garbage\.venv\lib\site-packages (from seaborn) (3.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in d:\kuliah\d4 - pens\proyek akhir\project\program\garbage\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in d:\kuliah\d4 - pens\proyek akhir\project\program\garbage\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\kuliah\d4 - pens\proyek akhir\project\program\garbage\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.52.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\kuliah\d4 - pens\proyek akhir\project\program\garbage\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in d:\kuliah\d4 - pens\proyek akhir\project\program\garbage\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.0)
# Requirement already satisfied: pillow>=8 in d:\kuliah\d4 - pens\proyek akhir\project\program\garbage\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\kuliah\d4 - pens\proyek akhir\project\program\garbage\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in d:\kuliah\d4 - pens\proyek akhir\project\program\garbage\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in d:\kuliah\d4 - pens\proyek akhir\project\program\garbage\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (6.4.0)
# Requirement already satisfied: pytz>=2020.1 in d:\kuliah\d4 - pens\proyek akhir\project\program\garbage\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\kuliah\d4 - pens\proyek akhir\project\program\garbage\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: zipp>=3.1.0 in d:\kuliah\d4 - pens\proyek akhir\project\program\garbage\.venv\lib\site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.4->seaborn) (3.19.0)
# Requirement already satisfied: six>=1.5 in d:\kuliah\d4 - pens\proyek akhir\project\program\garbage\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2

# %%
# !pip list
# Out:
# Package                      Version
# ---------------------------- -------------------
# absl-py                      2.1.0
# asttokens                    2.4.1
# astunparse                   1.6.3
# cachetools                   5.3.3
# certifi                      2024.2.2
# charset-normalizer           3.3.2
# colorama                     0.4.6
# comm                         0.2.2
# contourpy                    1.2.1
# cycler                       0.12.1
# debugpy                      1.8.1
# decorator                    5.1.1
# exceptiongroup               1.2.1
# executing                    2.0.1
# filelock                     3.13.1
# flatbuffers                  24.3.25
# fonttools                    4.52.4
# fsspec                       2024.2.0
# gast                         0.5.4
# google-auth                  2.29.0
# google-auth-oauthlib         0.4.6
# google-pasta                 0.2.0
# grpcio                       1.64.0
# h5py                         3.11.0
# idna                         3.7
# importlib_metadata           7.1.0
# importlib_resources          6.4.0
# intel-openmp                 2021.4.0
# ipykernel                    6.29.4
# ipython                      8.18.1
# jedi                         0.19.1
# Jinja2                       3.1.3
# joblib                       1.4.2
# jupyter_client               8.6.2
# jupyter_core                 5.7.2
# keras                        2.8.0
# Keras-Preprocessing          1.1.2
# kiwisolver                   1.4.5
# libclang                     18.1.1
# Markdown                     3.6
# MarkupSafe                   2.1.5
# matplotlib                   3.9.0
# matplotlib-inline            0.1.7
# mkl                          2021.4.0
# mpmath                       1.3.0
# nest-asyncio                 1.6.0
# networkx                     3.2.1
# numpy                        1.26.4
# oauthlib                     3.2.2
# opencv-python                4.9.0.80
# opt-einsum                   3.3.0
# packaging                    24.0
# pandas                       2.2.2
# parso                        0.8.4
# pillow                       10.3.0
# pip                          24.0
# platformdirs                 4.2.2
# prompt_toolkit               3.0.45
# protobuf                     3.20.0
# psutil                       5.9.8
# pure-eval                    0.2.2
# pyasn1                       0.6.0
# pyasn1_modules               0.4.0
# Pygments                     2.18.0
# pyparsing                    3.1.2
# python-dateutil              2.9.0.post0
# pytz                         2024.1
# pywin32                      306
# pyzmq                        26.0.3
# requests                     2.32.2
# requests-oauthlib            2.0.0
# rsa                          4.9
# scikit-learn                 1.5.0
# scipy                        1.13.1
# seaborn                      0.13.2
# setuptools                   58.1.0
# six                          1.16.0
# stack-data                   0.6.3
# sympy                        1.12
# tbb                          2021.11.0
# tensorboard                  2.8.0
# tensorboard-data-server      0.6.1
# tensorboard-plugin-wit       1.8.1
# tensorflow                   2.8.0
# tensorflow-gpu               2.8.0
# tensorflow-io-gcs-filesystem 0.31.0
# termcolor                    2.4.0
# tf-estimator-nightly         2.8.0.dev2021122109
# threadpoolctl                3.5.0
# torch                        2.3.0+cu118
# torchaudio                   2.3.0+cu118
# torchvision                  0.18.0+cu118
# tornado                      6.4
# traitlets                    5.14.3
# typing_extensions            4.12.0
# tzdata                       2024.1
# urllib3                      2.2.1
# wcwidth                      0.2.13
# Werkzeug                     3.0.3
# wheel                        0.43.0
# wrapt                        1.16.0
# zipp                         3.19.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report

# %%
# Predict on Test Set
y_test_pred = model.predict(X_test)
y_test_pred_classes = np.argmax(y_test_pred, axis=1)
y_test_true_classes = np.argmax(y_test, axis=1)


# Confusion Matrix
mat = confusion_matrix(y_test_true_classes, y_test_pred_classes)


# Class labels
def getClassName(class_no):
    classes = [
        "Not Littering",
        "Littering",
    ]
    return classes[class_no] if 0 <= class_no < len(classes) else "Unknown"


class_labels = [getClassName(i) for i in range(no_of_classes)]

sns.set()
plt.figure(figsize=(10, 8))
sns.heatmap(
    mat,
    square=True,
    annot=True,
    fmt="d",
    cbar=True,
    cmap="Blues",
    xticklabels=class_labels,
    yticklabels=class_labels,
)
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("Actual Label")
plt.show()

# %% [markdown]
# Classification Report

# %%
# Classification Report
report = classification_report(
    y_test_true_classes, y_test_pred_classes, target_names=class_labels
)
print(report)
# Out:
#                precision    recall  f1-score   support
#
# Not Littering       1.00      1.00      1.00        27
#     Littering       1.00      1.00      1.00        51
#
#      accuracy                           1.00        78
#     macro avg       1.00      1.00      1.00        78
#  weighted avg       1.00      1.00      1.00        78

# %% [markdown]
# Display Images with Predictions

# %%
# Display Images with Predictions
plt.figure(figsize=(10, 10))
indices = np.random.choice(len(X_test), 9, replace=False)
for i, index in enumerate(indices):
    ax = plt.subplot(3, 3, i + 1)
    img = X_test[index].reshape(image_dimensions[0], image_dimensions[1]) * 255.0
    plt.imshow(img.astype("uint8"), cmap="gray")
    plt.title(
        f"Predicted: {class_labels[y_test_pred_classes[index]]}\nActual: {class_labels[y_test_true_classes[index]]}"
    )
    plt.axis("off")
plt.show()

# %% [markdown]
# Prediction Function

# %%
def predict(path):
    imageShow = tf.keras.preprocessing.image.load_img(path, target_size=(72, 128))
    image = tf.keras.preprocessing.image.load_img(
        path, target_size=(72, 128), color_mode="grayscale"
    )
    image_array = tf.keras.preprocessing.image.img_to_array(image)
    image_array = tf.expand_dims(image_array, axis=0)  # Create batch axis
    image_array /= 255.0

    predictions = model.predict(image_array)
    for i, label in enumerate(class_labels):
        print(f"{label}: {predictions[0][i]}")
    score = predictions[0]
    predicted_class = np.argmax(score)
    prediction = class_labels[predicted_class]

    plt.imshow(imageShow)
    plt.title(prediction)
    plt.axis("off")
    plt.show()

# %%
predict("augmented_images/0/20240109_123839_tp00078 (0)_92.jpg")
predict("augmented_images/1/20240109_123839_tp00078 (1)_135.jpg")
# Out:
# Not Littering: 0.25503236055374146
# Littering: 0.7449676394462585
# Not Littering: 1.2679992472675039e-11
# Littering: 1.0
