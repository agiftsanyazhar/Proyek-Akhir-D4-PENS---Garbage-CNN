# %% [markdown]
# ## 1. Installation (Python 3.9.13)

# %%
# !pip install tensorflow==2.8.0 tensorflow-gpu==2.8.0 numpy matplotlib keras opencv-python scikit-learn pandas
# Out:
# Collecting tensorflow==2.8.0
#   Using cached tensorflow-2.8.0-cp39-cp39-win_amd64.whl.metadata (2.9 kB)
# Collecting tensorflow-gpu==2.8.0
#   Using cached tensorflow_gpu-2.8.0-cp39-cp39-win_amd64.whl.metadata (2.9 kB)
# Collecting numpy
#   Using cached numpy-1.26.4-cp39-cp39-win_amd64.whl.metadata (61 kB)
# Collecting matplotlib
#   Using cached matplotlib-3.9.0-cp39-cp39-win_amd64.whl.metadata (11 kB)
# Collecting keras
#   Using cached keras-3.3.3-py3-none-any.whl.metadata (5.7 kB)
# Collecting opencv-python
#   Using cached opencv_python-4.9.0.80-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Collecting scikit-learn
#   Using cached scikit_learn-1.5.0-cp39-cp39-win_amd64.whl.metadata (11 kB)
# Collecting pandas
#   Using cached pandas-2.2.2-cp39-cp39-win_amd64.whl.metadata (19 kB)
# Collecting absl-py>=0.4.0 (from tensorflow==2.8.0)
#   Using cached absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow==2.8.0)
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=1.12 (from tensorflow==2.8.0)
#   Using cached flatbuffers-24.3.25-py2.py3-none-any.whl.metadata (850 bytes)
# Collecting gast>=0.2.1 (from tensorflow==2.8.0)
#   Using cached gast-0.5.4-py3-none-any.whl.metadata (1.3 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow==2.8.0)
#   Using cached google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting h5py>=2.9.0 (from tensorflow==2.8.0)
#   Using cached h5py-3.11.0-cp39-cp39-win_amd64.whl.metadata (2.5 kB)
# Collecting keras-preprocessing>=1.1.1 (from tensorflow==2.8.0)
#   Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl.metadata (1.9 kB)
# Collecting libclang>=9.0.1 (from tensorflow==2.8.0)
#   Using cached libclang-18.1.1-py2.py3-none-win_amd64.whl.metadata (5.3 kB)
# Collecting opt-einsum>=2.3.2 (from tensorflow==2.8.0)
#   Using cached opt_einsum-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting protobuf>=3.9.2 (from tensorflow==2.8.0)
#   Using cached protobuf-5.27.0-cp39-cp39-win_amd64.whl.metadata (592 bytes)
# Requirement already satisfied: setuptools in d:\kuliah\d4 - pens\proyek akhir\project\program\garbage\.venv\lib\site-packages (from tensorflow==2.8.0) (58.1.0)
# Requirement already satisfied: six>=1.12.0 in d:\kuliah\d4 - pens\proyek akhir\project\program\garbage\.venv\lib\site-packages (from tensorflow==2.8.0) (1.16.0)
# Collecting termcolor>=1.1.0 (from tensorflow==2.8.0)
#   Using cached termcolor-2.4.0-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in d:\kuliah\d4 - pens\proyek akhir\project\program\garbage\.venv\lib\site-packages (from tensorflow==2.8.0) (4.12.0)
# Collecting wrapt>=1.11.0 (from tensorflow==2.8.0)
#   Using cached wrapt-1.16.0-cp39-cp39-win_amd64.whl.metadata (6.8 kB)
# Collecting tensorboard<2.9,>=2.8 (from tensorflow==2.8.0)
#   Using cached tensorboard-2.8.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting tf-estimator-nightly==2.8.0.dev2021122109 (from tensorflow==2.8.0)
#   Using cached tf_estimator_nightly-2.8.0.dev2021122109-py2.py3-none-any.whl.metadata (1.2 kB)
# Collecting keras
#   Using cached keras-2.8.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1 (from tensorflow==2.8.0)
#   Using cached tensorflow_io_gcs_filesystem-0.31.0-cp39-cp39-win_amd64.whl.metadata (14 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow==2.8.0)
#   Using cached grpcio-1.64.0-cp39-cp39-win_amd64.whl.metadata (3.4 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.2.1-cp39-cp39-win_amd64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Using cached fonttools-4.52.4-cp39-cp39-win_amd64.whl.metadata (164 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Using cached kiwisolver-1.4.5-cp39-cp39-win_amd64.whl.metadata (6.5 kB)
# Requirement already satisfied: packaging>=20.0 in d:\kuliah\d4 - pens\proyek akhir\project\program\garbage\.venv\lib\site-packages (from matplotlib) (24.0)
# Collecting pillow>=8 (from matplotlib)
#   Using cached pillow-10.3.0-cp39-cp39-win_amd64.whl.metadata (9.4 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Using cached pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in d:\kuliah\d4 - pens\proyek akhir\project\program\garbage\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Collecting importlib-resources>=3.2.0 (from matplotlib)
#   Using cached importlib_resources-6.4.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting scipy>=1.6.0 (from scikit-learn)
#   Using cached scipy-1.13.1-cp39-cp39-win_amd64.whl.metadata (60 kB)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Using cached threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting wheel<1.0,>=0.23.0 (from astunparse>=1.6.0->tensorflow==2.8.0)
#   Using cached wheel-0.43.0-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: zipp>=3.1.0 in d:\kuliah\d4 - pens\proyek akhir\project\program\garbage\.venv\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.19.0)
# Collecting google-auth<3,>=1.6.3 (from tensorboard<2.9,>=2.8->tensorflow==2.8.0)
#   Using cached google_auth-2.29.0-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting google-auth-oauthlib<0.5,>=0.4.1 (from tensorboard<2.9,>=2.8->tensorflow==2.8.0)
#   Using cached google_auth_oauthlib-0.4.6-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting markdown>=2.6.8 (from tensorboard<2.9,>=2.8->tensorflow==2.8.0)
#   Using cached Markdown-3.6-py3-none-any.whl.metadata (7.0 kB)
# Collecting requests<3,>=2.21.0 (from tensorboard<2.9,>=2.8->tensorflow==2.8.0)
#   Using cached requests-2.32.2-py3-none-any.whl.metadata (4.6 kB)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0 (from tensorboard<2.9,>=2.8->tensorflow==2.8.0)
#   Using cached tensorboard_data_server-0.6.1-py3-none-any.whl.metadata (1.1 kB)
# Collecting tensorboard-plugin-wit>=1.6.0 (from tensorboard<2.9,>=2.8->tensorflow==2.8.0)
#   Using cached tensorboard_plugin_wit-1.8.1-py3-none-any.whl.metadata (873 bytes)
# Collecting werkzeug>=0.11.15 (from tensorboard<2.9,>=2.8->tensorflow==2.8.0)
#   Using cached werkzeug-3.0.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0)
#   Using cached cachetools-5.3.3-py3-none-any.whl.metadata (5.3 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0)
#   Using cached pyasn1_modules-0.4.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0)
#   Using cached rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8.0)
#   Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: importlib-metadata>=4.4 in d:\kuliah\d4 - pens\proyek akhir\project\program\garbage\.venv\lib\site-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (7.1.0)
# Collecting charset-normalizer<4,>=2 (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.0)
#   Using cached charset_normalizer-3.3.2-cp39-cp39-win_amd64.whl.metadata (34 kB)
# Collecting idna<4,>=2.5 (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.0)
#   Using cached idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.0)
#   Using cached urllib3-2.2.1-py3-none-any.whl.metadata (6.4 kB)
# Collecting certifi>=2017.4.17 (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.0)
#   Using cached certifi-2024.2.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting MarkupSafe>=2.1.1 (from werkzeug>=0.11.15->tensorboard<2.9,>=2.8->tensorflow==2.8.0)
#   Using cached MarkupSafe-2.1.5-cp39-cp39-win_amd64.whl.metadata (3.1 kB)
# Collecting pyasn1<0.7.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0)
#   Using cached pyasn1-0.6.0-py2.py3-none-any.whl.metadata (8.3 kB)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8.0)
#   Using cached oauthlib-3.2.2-py3-none-any.whl.metadata (7.5 kB)
# Using cached tensorflow-2.8.0-cp39-cp39-win_amd64.whl (438.0 MB)
# Using cached tensorflow_gpu-2.8.0-cp39-cp39-win_amd64.whl (438.0 MB)
# Using cached tf_estimator_nightly-2.8.0.dev2021122109-py2.py3-none-any.whl (462 kB)
# Using cached numpy-1.26.4-cp39-cp39-win_amd64.whl (15.8 MB)
# Using cached matplotlib-3.9.0-cp39-cp39-win_amd64.whl (7.9 MB)
# Using cached keras-2.8.0-py2.py3-none-any.whl (1.4 MB)
# Using cached opencv_python-4.9.0.80-cp37-abi3-win_amd64.whl (38.6 MB)
# Using cached scikit_learn-1.5.0-cp39-cp39-win_amd64.whl (11.0 MB)
# Using cached pandas-2.2.2-cp39-cp39-win_amd64.whl (11.6 MB)
# Using cached absl_py-2.1.0-py3-none-any.whl (133 kB)
# Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Using cached contourpy-1.2.1-cp39-cp39-win_amd64.whl (182 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached flatbuffers-24.3.25-py2.py3-none-any.whl (26 kB)
# Using cached fonttools-4.52.4-cp39-cp39-win_amd64.whl (2.2 MB)
# Using cached gast-0.5.4-py3-none-any.whl (19 kB)
# Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Using cached grpcio-1.64.0-cp39-cp39-win_amd64.whl (4.1 MB)
# Using cached h5py-3.11.0-cp39-cp39-win_amd64.whl (3.0 MB)
# Using cached importlib_resources-6.4.0-py3-none-any.whl (38 kB)
# Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Using cached kiwisolver-1.4.5-cp39-cp39-win_amd64.whl (56 kB)
# Using cached libclang-18.1.1-py2.py3-none-win_amd64.whl (26.4 MB)
# Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Using cached pillow-10.3.0-cp39-cp39-win_amd64.whl (2.5 MB)
# Using cached protobuf-5.27.0-cp39-cp39-win_amd64.whl (426 kB)
# Using cached pyparsing-3.1.2-py3-none-any.whl (103 kB)
# Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Using cached scipy-1.13.1-cp39-cp39-win_amd64.whl (46.2 MB)
# Using cached tensorboard-2.8.0-py3-none-any.whl (5.8 MB)
# Using cached tensorflow_io_gcs_filesystem-0.31.0-cp39-cp39-win_amd64.whl (1.5 MB)
# Using cached termcolor-2.4.0-py3-none-any.whl (7.7 kB)
# Using cached threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# Using cached wrapt-1.16.0-cp39-cp39-win_amd64.whl (37 kB)
# Using cached google_auth-2.29.0-py2.py3-none-any.whl (189 kB)
# Using cached google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Using cached Markdown-3.6-py3-none-any.whl (105 kB)
# Using cached requests-2.32.2-py3-none-any.whl (63 kB)
# Using cached tensorboard_data_server-0.6.1-py3-none-any.whl (2.4 kB)
# Using cached tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
# Using cached werkzeug-3.0.3-py3-none-any.whl (227 kB)
# Using cached wheel-0.43.0-py3-none-any.whl (65 kB)
# Using cached cachetools-5.3.3-py3-none-any.whl (9.3 kB)
# Using cached certifi-2024.2.2-py3-none-any.whl (163 kB)
# Using cached charset_normalizer-3.3.2-cp39-cp39-win_amd64.whl (100 kB)
# Using cached idna-3.7-py3-none-any.whl (66 kB)
# Using cached MarkupSafe-2.1.5-cp39-cp39-win_amd64.whl (17 kB)
# Using cached pyasn1_modules-0.4.0-py3-none-any.whl (181 kB)
# Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Using cached urllib3-2.2.1-py3-none-any.whl (121 kB)
# Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Using cached pyasn1-0.6.0-py2.py3-none-any.whl (85 kB)
# Installing collected packages: tf-estimator-nightly, tensorboard-plugin-wit, pytz, libclang, keras, flatbuffers, wrapt, wheel, urllib3, tzdata, threadpoolctl, termcolor, tensorflow-io-gcs-filesystem, tensorboard-data-server, pyparsing, pyasn1, protobuf, pillow, oauthlib, numpy, MarkupSafe, kiwisolver, joblib, importlib-resources, idna, grpcio, google-pasta, gast, fonttools, cycler, charset-normalizer, certifi, cachetools, absl-py, werkzeug, scipy, rsa, requests, pyasn1-modules, pandas, opt-einsum, opencv-python, markdown, keras-preprocessing, h5py, contourpy, astunparse, scikit-learn, requests-oauthlib, matplotlib, google-auth, google-auth-oauthlib, tensorboard, tensorflow-gpu, tensorflow
# Successfully installed MarkupSafe-2.1.5 absl-py-2.1.0 astunparse-1.6.3 cachetools-5.3.3 certifi-2024.2.2 charset-normalizer-3.3.2 contourpy-1.2.1 cycler-0.12.1 flatbuffers-24.3.25 fonttools-4.52.4 gast-0.5.4 google-auth-2.29.0 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.64.0 h5py-3.11.0 idna-3.7 importlib-resources-6.4.0 joblib-1.4.2 keras-2.8.0 keras-preprocessing-1.1.2 kiwisolver-1.4.5 libclang-18.1.1 markdown-3.6 matplotlib-3.9.0 numpy-1.26.4 oauthlib-3.2.2 opencv-python-4.9.0.80 opt-einsum-3.3.0 pandas-2.2.2 pillow-10.3.0 protobuf-5.27.0 pyasn1-0.6.0 pyasn1-modules-0.4.0 pyparsing-3.1.2 pytz-2024.1 requests-2.32.2 requests-oauthlib-2.0.0 rsa-4.9 scikit-learn-1.5.0 scipy-1.13.1 tensorboard-2.8.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.8.0 tensorflow-gpu-2.8.0 tensorflow-io-gcs-filesystem-0.31.0 termcolor-2.4.0 tf-estimator-nightly-2.8.0.dev2021122109 threadpoolctl-3.5.0 tzdata-2024.1 urllib3-2.2.1 werkzeug-3.0.3 wheel-0.43.0 wrapt-1.16.0

# %%
# !pip install protobuf==3.20
# Out:
# Collecting protobuf==3.20
#   Using cached protobuf-3.20.0-cp39-cp39-win_amd64.whl.metadata (699 bytes)
# Using cached protobuf-3.20.0-cp39-cp39-win_amd64.whl (904 kB)
# Installing collected packages: protobuf
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.27.0
#     Uninstalling protobuf-5.27.0:
#       Successfully uninstalled protobuf-5.27.0
# Successfully installed protobuf-3.20.0

# %%
# !pip list
# Out:
# Package                      Version
# ---------------------------- -------------------
# absl-py                      2.1.0
# asttokens                    2.4.1
# astunparse                   1.6.3
# cachetools                   5.3.3
# certifi                      2024.2.2
# charset-normalizer           3.3.2
# colorama                     0.4.6
# comm                         0.2.2
# contourpy                    1.2.1
# cycler                       0.12.1
# debugpy                      1.8.1
# decorator                    5.1.1
# exceptiongroup               1.2.1
# executing                    2.0.1
# filelock                     3.13.1
# flatbuffers                  24.3.25
# fonttools                    4.52.4
# fsspec                       2024.2.0
# gast                         0.5.4
# google-auth                  2.29.0
# google-auth-oauthlib         0.4.6
# google-pasta                 0.2.0
# grpcio                       1.64.0
# h5py                         3.11.0
# idna                         3.7
# importlib_metadata           7.1.0
# importlib_resources          6.4.0
# intel-openmp                 2021.4.0
# ipykernel                    6.29.4
# ipython                      8.18.1
# jedi                         0.19.1
# Jinja2                       3.1.3
# joblib                       1.4.2
# jupyter_client               8.6.2
# jupyter_core                 5.7.2
# keras                        2.8.0
# Keras-Preprocessing          1.1.2
# kiwisolver                   1.4.5
# libclang                     18.1.1
# Markdown                     3.6
# MarkupSafe                   2.1.5
# matplotlib                   3.9.0
# matplotlib-inline            0.1.7
# mkl                          2021.4.0
# mpmath                       1.3.0
# nest-asyncio                 1.6.0
# networkx                     3.2.1
# numpy                        1.26.4
# oauthlib                     3.2.2
# opencv-python                4.9.0.80
# opt-einsum                   3.3.0
# packaging                    24.0
# pandas                       2.2.2
# parso                        0.8.4
# pillow                       10.3.0
# pip                          24.0
# platformdirs                 4.2.2
# prompt_toolkit               3.0.45
# protobuf                     3.20.0
# psutil                       5.9.8
# pure-eval                    0.2.2
# pyasn1                       0.6.0
# pyasn1_modules               0.4.0
# Pygments                     2.18.0
# pyparsing                    3.1.2
# python-dateutil              2.9.0.post0
# pytz                         2024.1
# pywin32                      306
# pyzmq                        26.0.3
# requests                     2.32.2
# requests-oauthlib            2.0.0
# rsa                          4.9
# scikit-learn                 1.5.0
# scipy                        1.13.1
# setuptools                   58.1.0
# six                          1.16.0
# stack-data                   0.6.3
# sympy                        1.12
# tbb                          2021.11.0
# tensorboard                  2.8.0
# tensorboard-data-server      0.6.1
# tensorboard-plugin-wit       1.8.1
# tensorflow                   2.8.0
# tensorflow-gpu               2.8.0
# tensorflow-io-gcs-filesystem 0.31.0
# termcolor                    2.4.0
# tf-estimator-nightly         2.8.0.dev2021122109
# threadpoolctl                3.5.0
# torch                        2.3.0+cu118
# torchaudio                   2.3.0+cu118
# torchvision                  0.18.0+cu118
# tornado                      6.4
# traitlets                    5.14.3
# typing_extensions            4.12.0
# tzdata                       2024.1
# urllib3                      2.2.1
# wcwidth                      0.2.13
# Werkzeug                     3.0.3
# wheel                        0.43.0
# wrapt                        1.16.0
# zipp                         3.19.0

# %% [markdown]
# ### 1.1 Limit Memory Growth

# %%
import os
import cv2
import tensorflow as tf
import numpy as np
from matplotlib import pyplot as plt

# %%
gpus = tf.config.experimental.list_physical_devices("GPU")

for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)

# %%
tf.config.list_physical_devices("GPU")
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## 2. Augmentation

# %% [markdown]
# ### 2.1 Albumentations Installation

# %%
# !pip install albumentations

# %%
# !pip install torch

# %% [markdown]
# ### 2.2 Setup Albumentations Transform

# %%
# import albumentations as alb
# from albumentations.pytorch import ToTensorV2

# %%
# augmentor = alb.Compose(
#     [
#         alb.Resize(width=128, height=128),
#         alb.HorizontalFlip(p=0.5),
#         alb.RandomBrightnessContrast(p=0.2),
#         alb.RandomGamma(p=0.2),
#         alb.RGBShift(p=0.2),
#         alb.VerticalFlip(p=0.5),
#     ],
# )

# %% [markdown]
# ### 2.3 Run Augmentation

# %%
# # Function to process a single image and its XML annotation
# def process_image(image_path):
#     # Load the image
#     image = cv2.imread(image_path)

#     for x in range(10):
#         # Apply the augmentation
#         augmented = augmentor(image=image)

#         augmented_image = augmented["image"]

#         # Save the augmented image and create a new XML file with the updated bounding boxes
#         augmented_image_path = image_path.replace("images", "augmented_images")
#         augmented_image_path = augmented_image_path.replace(".jpg", f"{x}.jpg")

#         os.makedirs(os.path.dirname(augmented_image_path), exist_ok=True)

#         cv2.imwrite(augmented_image_path, augmented_image)

# %%
# base_dir = "../Garbage/images"
# for root, dirs, files in os.walk(base_dir):
#     for file in files:
#         if file.endswith(".jpg"):
#             image_path = os.path.join(root, file)
#             process_image(image_path)

# %% [markdown]
# ## 3. Beginning of the Project

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
import cv2
from sklearn.model_selection import train_test_split
import pickle
import os
import pandas as pd
import random
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.layers import BatchNormalization

# %% [markdown]
# ### 3.1 Setup Parameters

# %%
path = "augmented_images_norm"
label_file = "labels.csv"
batch_size_val = 32  # Number of images to process together during training.
steps_per_epoch_val = 2000  # Baris ini mendefinisikan variabel steps_per_epoch_val yang menentukan jumlah iterasi pelatihan per epoch. Nilai 2000 berarti model akan dilatih selama 2000 iterasi setiap epoch.
epochs_val = 100
image_dimensions = (72, 128, 3) # Dimensions of the input images (height, width, channels).
test_ratio = 0.2  # If 1000 images split will 200 for testing (Baris ini mendefinisikan variabel testRatio yang menentukan proporsi data yang akan digunakan sebagai set tes. Nilai 0.2 berarti 20% dari data akan digunakan sebagai set tes, dan 80% sisanya akan digunakan sebagai set training dan validation).
validation_ratio = 0.1  # If 1000 images 20% of remaining 800 will be 160 for validation.

# %% [markdown]
# ### 3.2 Reads Images from Class Directories

# %%
count = 0
images = []
class_no = []
my_list = os.listdir(path)
print("Total Classes Detected:", len(my_list))
no_of_classes = len(my_list)
print("Importing Classes.....")
for x in range(0, len(my_list)):
    my_pic_list = os.listdir(path + "/" + str(count))  # Get list of images in current class directory.

    # Loop through each image in the class directory.
    for y in my_pic_list:
        cur_img = cv2.imread(path + "/" + str(count) + "/" + y)  # Read the image.
        images.append(cur_img)  # Append the image to the images list.
        class_no.append(count)  # Append the class number to the class_no list.
    print(count, end=" ")
    count += 1
print(" ")
images = np.array(images)  # Convert images list to numpy array.
class_no = np.array(class_no)  # Convert class_no list to numpy array.
# Out:
# Total Classes Detected: 2
# Importing Classes.....
# 0 1

# %% [markdown]
# ### 3.3 Split Images into Train, Val, and Test

# %%
# Split the dataset into training and testing sets, with the specified test ratio.
X_train, X_test, y_train, y_test = train_test_split(
    images, class_no, test_size=test_ratio
)

# Further split the training set into training and validation sets, with the specified validation ratio.
X_train, X_validation, y_train, y_validation = train_test_split(
    X_train, y_train, test_size=validation_ratio
)

# Calculate the number of steps per epoch for training and validation datasets, based on the batch size.
steps_per_epoch_val = len(X_train) // batch_size_val
validation_steps = len(X_test) // batch_size_val

# X_train = Array of images to train.
# y_train = Corresponding class id.

# %% [markdown]
# ### 3.4 Prints the Shapes of the Datasets to Ensure Consistency in the Number of Images and Labels

# %%
# Print the shapes of the datasets to check if the number of images matches the number of labels for each dataset.
print("Data Shapes")
print("Train", end="")
print(X_train.shape, y_train.shape)
print("Validation", end="")
print(X_validation.shape, y_validation.shape)
print("Test", end="")
print(X_test.shape, y_test.shape)

# Assert statements to ensure consistency in the number of images and labels across datasets and that image dimensions are correct.
assert (
    X_train.shape[0] == y_train.shape[0]
), "The number of images is not equal to the number of labels in training set"
assert (
    X_validation.shape[0] == y_validation.shape[0]
), "The number of images is not equal to the number of labels in validation set"
assert (
    X_test.shape[0] == y_test.shape[0]
), "The number of images is not equal to the number of labels in test set"
assert X_train.shape[1:] == (
    image_dimensions
), " The dimensions of the training images are wrong"
assert X_validation.shape[1:] == (
    image_dimensions
), " The dimensions of the validation images are wrong"
assert X_test.shape[1:] == (
    image_dimensions
), " The dimensions of the test images are wrong"
# Out:
# Data Shapes
# Train(743, 72, 128, 3) (743,)
# Validation(83, 72, 128, 3) (83,)
# Test(207, 72, 128, 3) (207,)

# %% [markdown]
# ### 3.5 Read CSV File (Labels)

# %%
data = pd.read_csv(label_file)

# %% [markdown]
# ### 3.6 Display Images of All the Classes

# %%
num_of_samples = []
cols = 5
num_classes = no_of_classes
fig, axs = plt.subplots(nrows=num_classes, ncols=cols, figsize=(5, 2))
fig.tight_layout()
for i in range(cols):
    for j, row in data.iterrows():
        x_selected = X_train[y_train == j]
        axs[j][i].imshow(
            x_selected[random.randint(0, len(x_selected) - 1), :, :],
            cmap=plt.get_cmap("gray"),
        )
        axs[j][i].axis("off")
        if i == 2:
            axs[j][i].set_title(str(j) + " - " + row["Name"])
            num_of_samples.append(len(x_selected))

# %% [markdown]
# ### 3.7 Distribution of the Dataset

# %%
# Calculate the number of samples for each class using the class labels.
num_of_samples_all = [np.sum(class_no == i) for i in range(no_of_classes)]

# Display the distribution of all images.
print(num_of_samples_all)
plt.figure(figsize=(12, 4))
plt.bar(range(0, no_of_classes), num_of_samples_all)
plt.title("Distribution of All Images")
plt.xlabel("Class Number")
plt.ylabel("Number of Images")
plt.show()
# Out:
# [470, 563]

# %% [markdown]
# ### 3.8 Distribution of the Training Dataset

# %%
print(num_of_samples)
sum(num_of_samples)
plt.figure(figsize=(12, 4))
plt.bar(range(0, num_classes), num_of_samples)
plt.title("Distribution of the Training Dataset")
plt.xlabel("Class Number")
plt.ylabel("Number of Images")
plt.show()
# Out:
# [324, 419]

# %% [markdown]
# ### 3.9 Preprocessing the Images

# %%
# # Convert the image to grayscale.
# def grayscale(img):
#     img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#     return img


# # Apply histogram equalization to standardize the lighting in the image.
# def equalize(img):
#     img = cv2.equalizeHist(img)
#     return img


def preprocessing(img):
#     img = grayscale(img)  
#     img = equalize(img)  
    img = img / 255  # Menormalisasi nilai piksel menjadi rentang 0 hingga 1.
    return img

# Menerapkan fungsi preprocessing ke setiap gambar dalam set pelatihan, validasi, dan tes
X_train = np.array(
    list(map(preprocessing, X_train))
)  
X_validation = np.array(list(map(preprocessing, X_validation)))
X_test = np.array(list(map(preprocessing, X_test)))

# %%
y_train = to_categorical(y_train, no_of_classes)
y_validation = to_categorical(y_validation, no_of_classes)
y_test = to_categorical(y_test, no_of_classes)

# %%
# X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], X_train.shape[2], 1)
# X_validation = X_validation.reshape(
#     X_validation.shape[0], X_validation.shape[1], X_validation.shape[2], 1
# )
# X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], X_test.shape[2], 1)

# %% [markdown]
# ### 3.10 CNN Model

# %%
# def myModel():
#     no_of_filters = 60
#     size_of_filter = (5, 5)  # The kernel size used for convolutional layers, which moves around the image to extract features.
#     size_of_filter2 = (3, 3)  # Another kernel size used for convolutional layers.
#     size_of_pool = (2, 2)  # The size of the pooling operation.
#     no_of_nodes = 500  # Number of nodes in the hidden layers of the neural network.

#     model = Sequential()
#     # Menambahkan lapisan konvolusi dengan aktivasi relu dan ukuran filter pertama.
#     model.add(
#         (
#             Conv2D(
#                 no_of_filters,
#                 size_of_filter,
#                 input_shape=(image_dimensions[0], image_dimensions[1], 1),
#                 activation="relu",
#             )
#         )
#     )
#     # Menambahkan lapisan konvolusi kedua dengan ukuran filter yang sama.
#     model.add((Conv2D(no_of_filters, size_of_filter, activation="relu")))
#     # Add a max pooling layer to downscale the feature maps.
#     model.add(MaxPooling2D(pool_size=size_of_pool))

#     # Menambahkan lapisan konvolusi ketiga dengan setengah jumlah filter.
#     model.add((Conv2D(no_of_filters // 2, size_of_filter2, activation="relu")))
#     # Menambahkan lapisan konvolusi keempat dengan setengah jumlah filter.
#     model.add((Conv2D(no_of_filters // 2, size_of_filter2, activation="relu")))
#     # Menambahkan lapisan pooling kedua.
#     model.add(MaxPooling2D(pool_size=size_of_pool))
#     # Menambahkan lapisan dropout untuk mengurangi overfitting.
#     model.add(Dropout(0.5))

#     # Flatten the output of the convolutional layers (menjadi vektor satu dimensi).
#     model.add(Flatten())
#     # Menambahkan dense hidden layer with ReLU activation dengan jumlah node yang ditentukan.
#     model.add(Dense(no_of_nodes, activation="relu"))
#     # Menambahkan lapisan dropout kedua.
#     model.add(Dropout(0.5))
#     # Menambahkan lapisan output akhir dengan jumlah node yang sama dengan jumlah kelas dan aktivasi softmax untuk klasifikasi multiclass.
#     model.add(Dense(no_of_classes, activation="softmax"))

#     # Compile the model with Adam optimizer, categorical crossentropy loss (untuk klasifikasi multiclass), and accuracy metric.
#     #
#     model.compile(
#         Adam(learning_rate=0.001), loss="categorical_crossentropy", metrics=["accuracy"]
#     )

#     return model

# %%
def myModel():
    no_of_filters = 64
    size_of_filter = (3, 3)
    size_of_filter2 = (3, 3)
    size_of_pool = (2, 2)
    no_of_nodes = 512

    model = Sequential()
    # Convolutional Layer 1
    model.add(
        Conv2D(
            no_of_filters,
            size_of_filter,
            input_shape=(image_dimensions[0], image_dimensions[1], 3),
            activation="relu",
        )
    )
    model.add(BatchNormalization())

    # Convolutional Layer 2
    model.add(Conv2D(no_of_filters, size_of_filter, activation="relu"))
    model.add(BatchNormalization())

    # MaxPooling dan Dropout untuk Layer Convolutional 1 dan 2
    model.add(MaxPooling2D(pool_size=size_of_pool))
    model.add(Dropout(0.3))

    # Convolutional Layer 3
    model.add(Conv2D(no_of_filters // 2, size_of_filter2, activation="relu"))
    model.add(BatchNormalization())

    # Convolutional Layer 4
    model.add(Conv2D(no_of_filters // 2, size_of_filter2, activation="relu"))
    model.add(BatchNormalization())

    # MaxPooling dan Dropout untuk Layer Convolutional 3 dan 4
    model.add(MaxPooling2D(pool_size=size_of_pool))
    model.add(Dropout(0.3))

    # Flatten Layer
    model.add(Flatten())

    # Dense Layer
    model.add(Dense(no_of_nodes, activation="relu"))
    model.add(Dropout(0.5))

    # Output Layer
    model.add(Dense(no_of_classes, activation="softmax"))

    model.compile(
        Adam(learning_rate=0.001), loss="categorical_crossentropy", metrics=["accuracy"]
    )
    return model

# %%
# Callback untuk menyimpan model dengan validasi terbaik selama pelatihan.
checkpoint = ModelCheckpoint(
    "people_garbage_without_preprocessing_norm_model_copy2.h5",
    verbose=1,  # Verbosity mode. 0 = silent, 1 = progress bar, 2 = one line per epoch.
    save_best_only=True,  # Indicates that only the model with the best validation loss will be saved.
)

# Callback untuk menghentikan pelatihan lebih awal jika tidak ada peningkatan.
early_stopping = EarlyStopping(
    monitor="val_loss",
    patience=10,  # Defines the number of epochs to wait without improvement before stopping training.
    restore_best_weights=True,  # Indicates that the model weights from the last epoch with the best validation loss should be loaded before resuming training if the training is restarted.
)

# Callback to reduce the learning rate if there is no improvement.
reduce_lr = ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.5,
    patience=5,  # Defines the number of epochs to wait without improvement before reducing the learning rate.
    min_lr=0.00001,  # Batas bawah laju pembelajaran.
)

# %%
model = myModel()
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 70, 126, 64)       1792
#
#  batch_normalization (BatchN  (None, 70, 126, 64)      256
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 68, 124, 64)       36928
#
#  batch_normalization_1 (Batc  (None, 68, 124, 64)      256
#  hNormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 34, 62, 64)       0
#  )
#
#  dropout (Dropout)           (None, 34, 62, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 32, 60, 32)        18464
#
#  batch_normalization_2 (Batc  (None, 32, 60, 32)       128
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 30, 58, 32)        9248
#
#  batch_normalization_3 (Batc  (None, 30, 58, 32)       128
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 15, 29, 32)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 15, 29, 32)        0
#
#  flatten (Flatten)           (None, 13920)             0
#
#  dense (Dense)               (None, 512)               7127552
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 2)                 1026
#
# =================================================================
# Total params: 7,195,778
# Trainable params: 7,195,394
# Non-trainable params: 384
# _________________________________________________________________
# None

# %%
# !nvidia-smi
# Out:
# Thu Jun 27 20:15:46 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 552.44                 Driver Version: 552.44         CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                     TCC/WDDM  | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4050 ...  WDDM  |   00000000:01:00.0 Off |                  N/A |
# | N/A   48C    P0             15W /   85W |    5902MiB /   6141MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A     11784      C   ...Programs\Python\Python39\python.exe      N/A      |
# |    0   N/A  N/A     18588      C   ...Programs\Python\Python39\python.exe      N/A      |
# |    0   N/A  N/A     22812      C   ...rograms\Python\Python310\python.exe      N/A      |
# |    0   N/A  N/A     23676      C   ...Programs\Python\Python39\python.exe      N/A      |
# |    0   N/A  N/A     30716      C   ...Programs\Python\Python39\python.exe      N/A      |
# |    0   N/A  N/A     31840      C   ...Programs\Python\Python39\python.exe      N/A      |
# +-----------------------------------------------------------------------------------------+

# %%
history = model.fit(
    X_train,
    y_train,
    batch_size=batch_size_val,
    steps_per_epoch=steps_per_epoch_val,
    epochs=epochs_val,
    callbacks=[checkpoint, early_stopping, reduce_lr],
    validation_data=(X_validation, y_validation),
    shuffle=True,
)
# Out:
# Epoch 1/100
# 23/23 [==============================] - ETA: 0s - loss: 2.1671 - accuracy: 0.8573
# Epoch 1: val_loss improved from inf to 1.15801, saving model to people_garbage_without_preprocessing_norm_model_copy2.h5
# 23/23 [==============================] - 6s 107ms/step - loss: 2.1671 - accuracy: 0.8573 - val_loss: 1.1580 - val_accuracy: 0.6747 - lr: 0.0010
# Epoch 2/100
# 23/23 [==============================] - ETA: 0s - loss: 0.9171 - accuracy: 0.9353
# Epoch 2: val_loss did not improve from 1.15801
# 23/23 [==============================] - 2s 38ms/step - loss: 0.9171 - accuracy: 0.9353 - val_loss: 1.6471 - val_accuracy: 0.5904 - lr: 0.0010
# Epoch 3/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.1538 - accuracy: 0.9735
# Epoch 3: val_loss did not improve from 1.15801
# 23/23 [==============================] - 1s 36ms/step - loss: 0.1469 - accuracy: 0.9747 - val_loss: 2.3240 - val_accuracy: 0.4217 - lr: 0.0010
# Epoch 4/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.1006 - accuracy: 0.9779
# Epoch 4: val_loss did not improve from 1.15801
# 23/23 [==============================] - 1s 37ms/step - loss: 0.1102 - accuracy: 0.9775 - val_loss: 4.8153 - val_accuracy: 0.4217 - lr: 0.0010
# Epoch 5/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.0632 - accuracy: 0.9853
# Epoch 5: val_loss improved from 1.15801 to 0.34356, saving model to people_garbage_without_preprocessing_norm_model_copy2.h5
# 23/23 [==============================] - 1s 47ms/step - loss: 0.0628 - accuracy: 0.9845 - val_loss: 0.3436 - val_accuracy: 0.6747 - lr: 0.0010
# Epoch 6/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.0817 - accuracy: 0.9779
# Epoch 6: val_loss did not improve from 0.34356
# 23/23 [==============================] - 1s 36ms/step - loss: 0.0780 - accuracy: 0.9789 - val_loss: 1.9799 - val_accuracy: 0.4217 - lr: 0.0010
# Epoch 7/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.0432 - accuracy: 0.9882
# Epoch 7: val_loss improved from 0.34356 to 0.12141, saving model to people_garbage_without_preprocessing_norm_model_copy2.h5
# 23/23 [==============================] - 1s 46ms/step - loss: 0.0413 - accuracy: 0.9887 - val_loss: 0.1214 - val_accuracy: 0.8916 - lr: 0.0010
# Epoch 8/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.0154 - accuracy: 0.9956
# Epoch 8: val_loss did not improve from 0.12141
# 23/23 [==============================] - 1s 36ms/step - loss: 0.0147 - accuracy: 0.9958 - val_loss: 0.1774 - val_accuracy: 0.8795 - lr: 0.0010
# Epoch 9/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.0316 - accuracy: 0.9912
# Epoch 9: val_loss improved from 0.12141 to 0.05417, saving model to people_garbage_without_preprocessing_norm_model_copy2.h5
# 23/23 [==============================] - 1s 46ms/step - loss: 0.0305 - accuracy: 0.9916 - val_loss: 0.0542 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 10/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.0219 - accuracy: 0.9926
# Epoch 10: val_loss did not improve from 0.05417
# 23/23 [==============================] - 1s 37ms/step - loss: 0.0209 - accuracy: 0.9930 - val_loss: 0.0593 - val_accuracy: 0.9759 - lr: 0.0010
# Epoch 11/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.0816 - accuracy: 0.9809
# Epoch 11: val_loss did not improve from 0.05417
# 23/23 [==============================] - 1s 36ms/step - loss: 0.0780 - accuracy: 0.9817 - val_loss: 0.1926 - val_accuracy: 0.9277 - lr: 0.0010
# Epoch 12/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.0057 - accuracy: 0.9971
# Epoch 12: val_loss did not improve from 0.05417
# 23/23 [==============================] - 1s 36ms/step - loss: 0.0055 - accuracy: 0.9972 - val_loss: 0.1564 - val_accuracy: 0.9277 - lr: 0.0010
# Epoch 13/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.0188 - accuracy: 0.9926
# Epoch 13: val_loss did not improve from 0.05417
# 23/23 [==============================] - 1s 36ms/step - loss: 0.0180 - accuracy: 0.9930 - val_loss: 0.0911 - val_accuracy: 0.9518 - lr: 0.0010
# Epoch 14/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.0015 - accuracy: 1.0000
# Epoch 14: val_loss improved from 0.05417 to 0.01492, saving model to people_garbage_without_preprocessing_norm_model_copy2.h5
# 23/23 [==============================] - 1s 45ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0149 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 15/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.0103 - accuracy: 0.9971
# Epoch 15: val_loss did not improve from 0.01492
# 23/23 [==============================] - 1s 36ms/step - loss: 0.0101 - accuracy: 0.9972 - val_loss: 0.0197 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 16/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.0049 - accuracy: 0.9985
# Epoch 16: val_loss improved from 0.01492 to 0.01284, saving model to people_garbage_without_preprocessing_norm_model_copy2.h5
# 23/23 [==============================] - 1s 46ms/step - loss: 0.0047 - accuracy: 0.9986 - val_loss: 0.0128 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 17/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.0032 - accuracy: 0.9985
# Epoch 17: val_loss did not improve from 0.01284
# 23/23 [==============================] - 1s 37ms/step - loss: 0.0031 - accuracy: 0.9986 - val_loss: 0.0307 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 18/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.0080 - accuracy: 0.9985
# Epoch 18: val_loss did not improve from 0.01284
# 23/23 [==============================] - 1s 36ms/step - loss: 0.0077 - accuracy: 0.9986 - val_loss: 0.0221 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 19/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.0101 - accuracy: 0.9971
# Epoch 19: val_loss did not improve from 0.01284
# 23/23 [==============================] - 1s 37ms/step - loss: 0.0098 - accuracy: 0.9972 - val_loss: 0.2463 - val_accuracy: 0.8795 - lr: 0.0010
# Epoch 20/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000
# Epoch 20: val_loss did not improve from 0.01284
# 23/23 [==============================] - 1s 36ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0645 - val_accuracy: 0.9639 - lr: 0.0010
# Epoch 21/100
# 22/23 [===========================>..] - ETA: 0s - loss: 4.1502e-05 - accuracy: 1.0000
# Epoch 21: val_loss did not improve from 0.01284
# 23/23 [==============================] - 1s 36ms/step - loss: 4.0395e-05 - accuracy: 1.0000 - val_loss: 0.0349 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 22/100
# 22/23 [===========================>..] - ETA: 0s - loss: 1.0454e-04 - accuracy: 1.0000
# Epoch 22: val_loss did not improve from 0.01284
# 23/23 [==============================] - 1s 36ms/step - loss: 1.0545e-04 - accuracy: 1.0000 - val_loss: 0.0204 - val_accuracy: 1.0000 - lr: 5.0000e-04
# Epoch 23/100
# 21/23 [==========================>...] - ETA: 0s - loss: 4.8253e-05 - accuracy: 1.0000
# Epoch 23: val_loss improved from 0.01284 to 0.01016, saving model to people_garbage_without_preprocessing_norm_model_copy2.h5
# 23/23 [==============================] - 1s 46ms/step - loss: 4.9991e-05 - accuracy: 1.0000 - val_loss: 0.0102 - val_accuracy: 1.0000 - lr: 5.0000e-04
# Epoch 24/100
# 21/23 [==========================>...] - ETA: 0s - loss: 4.1334e-05 - accuracy: 1.0000
# Epoch 24: val_loss improved from 0.01016 to 0.00549, saving model to people_garbage_without_preprocessing_norm_model_copy2.h5
# 23/23 [==============================] - 1s 46ms/step - loss: 3.9104e-05 - accuracy: 1.0000 - val_loss: 0.0055 - val_accuracy: 1.0000 - lr: 5.0000e-04
# Epoch 25/100
# 23/23 [==============================] - ETA: 0s - loss: 3.1968e-04 - accuracy: 1.0000
# Epoch 25: val_loss improved from 0.00549 to 0.00310, saving model to people_garbage_without_preprocessing_norm_model_copy2.h5
# 23/23 [==============================] - 1s 47ms/step - loss: 3.1968e-04 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000 - lr: 5.0000e-04
# Epoch 26/100
# 23/23 [==============================] - ETA: 0s - loss: 2.4875e-04 - accuracy: 1.0000
# Epoch 26: val_loss improved from 0.00310 to 0.00149, saving model to people_garbage_without_preprocessing_norm_model_copy2.h5
# 23/23 [==============================] - 1s 48ms/step - loss: 2.4875e-04 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 1.0000 - lr: 5.0000e-04
# Epoch 27/100
# 22/23 [===========================>..] - ETA: 0s - loss: 1.9467e-05 - accuracy: 1.0000
# Epoch 27: val_loss improved from 0.00149 to 0.00070, saving model to people_garbage_without_preprocessing_norm_model_copy2.h5
# 23/23 [==============================] - 1s 46ms/step - loss: 1.9429e-05 - accuracy: 1.0000 - val_loss: 7.0439e-04 - val_accuracy: 1.0000 - lr: 5.0000e-04
# Epoch 28/100
# 22/23 [===========================>..] - ETA: 0s - loss: 5.0093e-05 - accuracy: 1.0000
# Epoch 28: val_loss improved from 0.00070 to 0.00031, saving model to people_garbage_without_preprocessing_norm_model_copy2.h5
# 23/23 [==============================] - 1s 47ms/step - loss: 4.9768e-05 - accuracy: 1.0000 - val_loss: 3.0901e-04 - val_accuracy: 1.0000 - lr: 5.0000e-04
# Epoch 29/100
# 22/23 [===========================>..] - ETA: 0s - loss: 9.0893e-05 - accuracy: 1.0000
# Epoch 29: val_loss improved from 0.00031 to 0.00015, saving model to people_garbage_without_preprocessing_norm_model_copy2.h5
# 23/23 [==============================] - 1s 44ms/step - loss: 8.9827e-05 - accuracy: 1.0000 - val_loss: 1.4615e-04 - val_accuracy: 1.0000 - lr: 5.0000e-04
# Epoch 30/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.0012 - accuracy: 1.0000
# Epoch 30: val_loss improved from 0.00015 to 0.00009, saving model to people_garbage_without_preprocessing_norm_model_copy2.h5
# 23/23 [==============================] - 1s 44ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 8.5565e-05 - val_accuracy: 1.0000 - lr: 5.0000e-04
# Epoch 31/100
# 22/23 [===========================>..] - ETA: 0s - loss: 5.9549e-05 - accuracy: 1.0000
# Epoch 31: val_loss improved from 0.00009 to 0.00007, saving model to people_garbage_without_preprocessing_norm_model_copy2.h5
# 23/23 [==============================] - 1s 44ms/step - loss: 5.7266e-05 - accuracy: 1.0000 - val_loss: 6.5203e-05 - val_accuracy: 1.0000 - lr: 5.0000e-04
# Epoch 32/100
# 22/23 [===========================>..] - ETA: 0s - loss: 3.2694e-04 - accuracy: 1.0000
# Epoch 32: val_loss improved from 0.00007 to 0.00002, saving model to people_garbage_without_preprocessing_norm_model_copy2.h5
# 23/23 [==============================] - 1s 43ms/step - loss: 3.1613e-04 - accuracy: 1.0000 - val_loss: 2.1985e-05 - val_accuracy: 1.0000 - lr: 5.0000e-04
# Epoch 33/100
# 22/23 [===========================>..] - ETA: 0s - loss: 3.2200e-05 - accuracy: 1.0000
# Epoch 33: val_loss improved from 0.00002 to 0.00001, saving model to people_garbage_without_preprocessing_norm_model_copy2.h5
# 23/23 [==============================] - 1s 44ms/step - loss: 7.6408e-05 - accuracy: 1.0000 - val_loss: 1.0588e-05 - val_accuracy: 1.0000 - lr: 5.0000e-04
# Epoch 34/100
# 22/23 [===========================>..] - ETA: 0s - loss: 4.2950e-05 - accuracy: 1.0000
# Epoch 34: val_loss improved from 0.00001 to 0.00001, saving model to people_garbage_without_preprocessing_norm_model_copy2.h5
# 23/23 [==============================] - 1s 45ms/step - loss: 4.1106e-05 - accuracy: 1.0000 - val_loss: 7.1608e-06 - val_accuracy: 1.0000 - lr: 5.0000e-04
# Epoch 35/100
# 22/23 [===========================>..] - ETA: 0s - loss: 2.4357e-04 - accuracy: 1.0000
# Epoch 35: val_loss improved from 0.00001 to 0.00001, saving model to people_garbage_without_preprocessing_norm_model_copy2.h5
# 23/23 [==============================] - 1s 44ms/step - loss: 2.3327e-04 - accuracy: 1.0000 - val_loss: 7.0487e-06 - val_accuracy: 1.0000 - lr: 5.0000e-04
# Epoch 36/100
# 22/23 [===========================>..] - ETA: 0s - loss: 3.3581e-04 - accuracy: 1.0000
# Epoch 36: val_loss improved from 0.00001 to 0.00000, saving model to people_garbage_without_preprocessing_norm_model_copy2.h5
# 23/23 [==============================] - 1s 44ms/step - loss: 3.2070e-04 - accuracy: 1.0000 - val_loss: 2.4904e-06 - val_accuracy: 1.0000 - lr: 5.0000e-04
# Epoch 37/100
# 22/23 [===========================>..] - ETA: 0s - loss: 2.3162e-04 - accuracy: 1.0000
# Epoch 37: val_loss improved from 0.00000 to 0.00000, saving model to people_garbage_without_preprocessing_norm_model_copy2.h5
# 23/23 [==============================] - 1s 43ms/step - loss: 2.2121e-04 - accuracy: 1.0000 - val_loss: 2.0739e-06 - val_accuracy: 1.0000 - lr: 5.0000e-04
# Epoch 38/100
# 22/23 [===========================>..] - ETA: 0s - loss: 1.1223e-04 - accuracy: 1.0000
# Epoch 38: val_loss improved from 0.00000 to 0.00000, saving model to people_garbage_without_preprocessing_norm_model_copy2.h5
# 23/23 [==============================] - 1s 43ms/step - loss: 1.0721e-04 - accuracy: 1.0000 - val_loss: 1.3730e-06 - val_accuracy: 1.0000 - lr: 2.5000e-04
# Epoch 39/100
# 22/23 [===========================>..] - ETA: 0s - loss: 3.2292e-06 - accuracy: 1.0000
# Epoch 39: val_loss improved from 0.00000 to 0.00000, saving model to people_garbage_without_preprocessing_norm_model_copy2.h5
# 23/23 [==============================] - 1s 45ms/step - loss: 3.2393e-06 - accuracy: 1.0000 - val_loss: 9.7665e-07 - val_accuracy: 1.0000 - lr: 2.5000e-04
# Epoch 40/100
# 22/23 [===========================>..] - ETA: 0s - loss: 4.0093e-05 - accuracy: 1.0000
# Epoch 40: val_loss improved from 0.00000 to 0.00000, saving model to people_garbage_without_preprocessing_norm_model_copy2.h5
# 23/23 [==============================] - 1s 44ms/step - loss: 3.8288e-05 - accuracy: 1.0000 - val_loss: 7.3967e-07 - val_accuracy: 1.0000 - lr: 2.5000e-04
# Epoch 41/100
# 22/23 [===========================>..] - ETA: 0s - loss: 2.8171e-05 - accuracy: 1.0000
# Epoch 41: val_loss improved from 0.00000 to 0.00000, saving model to people_garbage_without_preprocessing_norm_model_copy2.h5
# 23/23 [==============================] - 1s 45ms/step - loss: 2.7088e-05 - accuracy: 1.0000 - val_loss: 5.9174e-07 - val_accuracy: 1.0000 - lr: 2.5000e-04
# Epoch 42/100
# 22/23 [===========================>..] - ETA: 0s - loss: 3.7064e-06 - accuracy: 1.0000
# Epoch 42: val_loss improved from 0.00000 to 0.00000, saving model to people_garbage_without_preprocessing_norm_model_copy2.h5
# 23/23 [==============================] - 1s 43ms/step - loss: 3.5974e-06 - accuracy: 1.0000 - val_loss: 5.1131e-07 - val_accuracy: 1.0000 - lr: 2.5000e-04
# Epoch 43/100
# 22/23 [===========================>..] - ETA: 0s - loss: 1.3736e-05 - accuracy: 1.0000
# Epoch 43: val_loss improved from 0.00000 to 0.00000, saving model to people_garbage_without_preprocessing_norm_model_copy2.h5
# 23/23 [==============================] - 1s 45ms/step - loss: 1.4724e-05 - accuracy: 1.0000 - val_loss: 4.4667e-07 - val_accuracy: 1.0000 - lr: 1.2500e-04
# Epoch 44/100
# 22/23 [===========================>..] - ETA: 0s - loss: 1.2063e-04 - accuracy: 1.0000
# Epoch 44: val_loss improved from 0.00000 to 0.00000, saving model to people_garbage_without_preprocessing_norm_model_copy2.h5
# 23/23 [==============================] - 1s 44ms/step - loss: 1.1527e-04 - accuracy: 1.0000 - val_loss: 3.5763e-07 - val_accuracy: 1.0000 - lr: 1.2500e-04
# Epoch 45/100
# 22/23 [===========================>..] - ETA: 0s - loss: 1.0242e-05 - accuracy: 1.0000
# Epoch 45: val_loss improved from 0.00000 to 0.00000, saving model to people_garbage_without_preprocessing_norm_model_copy2.h5
# 23/23 [==============================] - 1s 44ms/step - loss: 9.7946e-06 - accuracy: 1.0000 - val_loss: 2.9300e-07 - val_accuracy: 1.0000 - lr: 1.2500e-04
# Epoch 46/100
# 22/23 [===========================>..] - ETA: 0s - loss: 1.6822e-05 - accuracy: 1.0000
# Epoch 46: val_loss improved from 0.00000 to 0.00000, saving model to people_garbage_without_preprocessing_norm_model_copy2.h5
# 23/23 [==============================] - 1s 43ms/step - loss: 1.7408e-05 - accuracy: 1.0000 - val_loss: 2.7576e-07 - val_accuracy: 1.0000 - lr: 1.2500e-04
# Epoch 47/100
# 21/23 [==========================>...] - ETA: 0s - loss: 4.7499e-05 - accuracy: 1.0000
# Epoch 47: val_loss improved from 0.00000 to 0.00000, saving model to people_garbage_without_preprocessing_norm_model_copy2.h5
# 23/23 [==============================] - 1s 44ms/step - loss: 4.4968e-05 - accuracy: 1.0000 - val_loss: 2.6427e-07 - val_accuracy: 1.0000 - lr: 1.2500e-04
# Epoch 48/100
# 21/23 [==========================>...] - ETA: 0s - loss: 1.6071e-04 - accuracy: 1.0000
# Epoch 48: val_loss improved from 0.00000 to 0.00000, saving model to people_garbage_without_preprocessing_norm_model_copy2.h5
# 23/23 [==============================] - 1s 44ms/step - loss: 1.5190e-04 - accuracy: 1.0000 - val_loss: 2.5565e-07 - val_accuracy: 1.0000 - lr: 6.2500e-05
# Epoch 49/100
# 23/23 [==============================] - ETA: 0s - loss: 6.6781e-06 - accuracy: 1.0000
# Epoch 49: val_loss improved from 0.00000 to 0.00000, saving model to people_garbage_without_preprocessing_norm_model_copy2.h5
# 23/23 [==============================] - 1s 47ms/step - loss: 6.6781e-06 - accuracy: 1.0000 - val_loss: 2.5134e-07 - val_accuracy: 1.0000 - lr: 6.2500e-05
# Epoch 50/100
# 23/23 [==============================] - ETA: 0s - loss: 7.4351e-06 - accuracy: 1.0000
# Epoch 50: val_loss improved from 0.00000 to 0.00000, saving model to people_garbage_without_preprocessing_norm_model_copy2.h5
# 23/23 [==============================] - 1s 45ms/step - loss: 7.4351e-06 - accuracy: 1.0000 - val_loss: 2.4704e-07 - val_accuracy: 1.0000 - lr: 6.2500e-05
# Epoch 51/100
# 22/23 [===========================>..] - ETA: 0s - loss: 2.9354e-06 - accuracy: 1.0000
# Epoch 51: val_loss improved from 0.00000 to 0.00000, saving model to people_garbage_without_preprocessing_norm_model_copy2.h5
# 23/23 [==============================] - 1s 44ms/step - loss: 2.9796e-06 - accuracy: 1.0000 - val_loss: 2.4560e-07 - val_accuracy: 1.0000 - lr: 6.2500e-05
# Epoch 52/100
# 22/23 [===========================>..] - ETA: 0s - loss: 8.7956e-06 - accuracy: 1.0000
# Epoch 52: val_loss improved from 0.00000 to 0.00000, saving model to people_garbage_without_preprocessing_norm_model_copy2.h5
# 23/23 [==============================] - 1s 44ms/step - loss: 1.0375e-05 - accuracy: 1.0000 - val_loss: 2.4129e-07 - val_accuracy: 1.0000 - lr: 6.2500e-05
# Epoch 53/100
# 22/23 [===========================>..] - ETA: 0s - loss: 7.7009e-06 - accuracy: 1.0000
# Epoch 53: val_loss improved from 0.00000 to 0.00000, saving model to people_garbage_without_preprocessing_norm_model_copy2.h5
# 23/23 [==============================] - 1s 44ms/step - loss: 7.4149e-06 - accuracy: 1.0000 - val_loss: 2.3698e-07 - val_accuracy: 1.0000 - lr: 3.1250e-05
# Epoch 54/100
# 22/23 [===========================>..] - ETA: 0s - loss: 5.4539e-05 - accuracy: 1.0000
# Epoch 54: val_loss did not improve from 0.00000
# 23/23 [==============================] - 1s 36ms/step - loss: 5.2304e-05 - accuracy: 1.0000 - val_loss: 2.3985e-07 - val_accuracy: 1.0000 - lr: 3.1250e-05
# Epoch 55/100
# 22/23 [===========================>..] - ETA: 0s - loss: 1.4052e-05 - accuracy: 1.0000
# Epoch 55: val_loss improved from 0.00000 to 0.00000, saving model to people_garbage_without_preprocessing_norm_model_copy2.h5
# 23/23 [==============================] - 1s 43ms/step - loss: 1.3482e-05 - accuracy: 1.0000 - val_loss: 2.3411e-07 - val_accuracy: 1.0000 - lr: 3.1250e-05
# Epoch 56/100
# 22/23 [===========================>..] - ETA: 0s - loss: 6.6431e-06 - accuracy: 1.0000
# Epoch 56: val_loss improved from 0.00000 to 0.00000, saving model to people_garbage_without_preprocessing_norm_model_copy2.h5
# 23/23 [==============================] - 1s 44ms/step - loss: 6.4176e-06 - accuracy: 1.0000 - val_loss: 2.3267e-07 - val_accuracy: 1.0000 - lr: 3.1250e-05
# Epoch 57/100
# 22/23 [===========================>..] - ETA: 0s - loss: 1.4755e-05 - accuracy: 1.0000
# Epoch 57: val_loss improved from 0.00000 to 0.00000, saving model to people_garbage_without_preprocessing_norm_model_copy2.h5
# 23/23 [==============================] - 1s 43ms/step - loss: 1.4260e-05 - accuracy: 1.0000 - val_loss: 2.2836e-07 - val_accuracy: 1.0000 - lr: 3.1250e-05
# Epoch 58/100
# 22/23 [===========================>..] - ETA: 0s - loss: 1.0510e-05 - accuracy: 1.0000
# Epoch 58: val_loss did not improve from 0.00000
# 23/23 [==============================] - 1s 36ms/step - loss: 1.0188e-05 - accuracy: 1.0000 - val_loss: 2.2980e-07 - val_accuracy: 1.0000 - lr: 1.5625e-05
# Epoch 59/100
# 22/23 [===========================>..] - ETA: 0s - loss: 1.7946e-05 - accuracy: 1.0000
# Epoch 59: val_loss did not improve from 0.00000
# 23/23 [==============================] - 1s 36ms/step - loss: 1.7293e-05 - accuracy: 1.0000 - val_loss: 2.3124e-07 - val_accuracy: 1.0000 - lr: 1.5625e-05
# Epoch 60/100
# 22/23 [===========================>..] - ETA: 0s - loss: 1.0709e-05 - accuracy: 1.0000
# Epoch 60: val_loss did not improve from 0.00000
# 23/23 [==============================] - 1s 37ms/step - loss: 1.0247e-05 - accuracy: 1.0000 - val_loss: 2.2980e-07 - val_accuracy: 1.0000 - lr: 1.5625e-05
# Epoch 61/100
# 22/23 [===========================>..] - ETA: 0s - loss: 1.8105e-06 - accuracy: 1.0000
# Epoch 61: val_loss improved from 0.00000 to 0.00000, saving model to people_garbage_without_preprocessing_norm_model_copy2.h5
# 23/23 [==============================] - 1s 44ms/step - loss: 2.6599e-06 - accuracy: 1.0000 - val_loss: 2.2693e-07 - val_accuracy: 1.0000 - lr: 1.5625e-05
# Epoch 62/100
# 22/23 [===========================>..] - ETA: 0s - loss: 2.7071e-05 - accuracy: 1.0000
# Epoch 62: val_loss improved from 0.00000 to 0.00000, saving model to people_garbage_without_preprocessing_norm_model_copy2.h5
# 23/23 [==============================] - 1s 44ms/step - loss: 2.5891e-05 - accuracy: 1.0000 - val_loss: 2.2549e-07 - val_accuracy: 1.0000 - lr: 1.5625e-05
# Epoch 63/100
# 22/23 [===========================>..] - ETA: 0s - loss: 1.2865e-05 - accuracy: 1.0000
# Epoch 63: val_loss improved from 0.00000 to 0.00000, saving model to people_garbage_without_preprocessing_norm_model_copy2.h5
# 23/23 [==============================] - 1s 44ms/step - loss: 1.2329e-05 - accuracy: 1.0000 - val_loss: 2.2406e-07 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 64/100
# 22/23 [===========================>..] - ETA: 0s - loss: 7.6634e-06 - accuracy: 1.0000
# Epoch 64: val_loss improved from 0.00000 to 0.00000, saving model to people_garbage_without_preprocessing_norm_model_copy2.h5
# 23/23 [==============================] - 1s 44ms/step - loss: 7.3211e-06 - accuracy: 1.0000 - val_loss: 2.2118e-07 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 65/100
# 22/23 [===========================>..] - ETA: 0s - loss: 2.5476e-05 - accuracy: 1.0000
# Epoch 65: val_loss did not improve from 0.00000
# 23/23 [==============================] - 1s 36ms/step - loss: 2.4331e-05 - accuracy: 1.0000 - val_loss: 2.2549e-07 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 66/100
# 22/23 [===========================>..] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000
# Epoch 66: val_loss improved from 0.00000 to 0.00000, saving model to people_garbage_without_preprocessing_norm_model_copy2.h5
# 23/23 [==============================] - 1s 46ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 2.1831e-07 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 67/100
# 22/23 [===========================>..] - ETA: 0s - loss: 3.2226e-05 - accuracy: 1.0000
# Epoch 67: val_loss did not improve from 0.00000
# 23/23 [==============================] - 1s 36ms/step - loss: 3.0937e-05 - accuracy: 1.0000 - val_loss: 2.2262e-07 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 68/100
# 22/23 [===========================>..] - ETA: 0s - loss: 2.0670e-05 - accuracy: 1.0000
# Epoch 68: val_loss did not improve from 0.00000
# 23/23 [==============================] - 1s 36ms/step - loss: 1.9766e-05 - accuracy: 1.0000 - val_loss: 2.3124e-07 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 69/100
# 22/23 [===========================>..] - ETA: 0s - loss: 2.2986e-05 - accuracy: 1.0000
# Epoch 69: val_loss did not improve from 0.00000
# 23/23 [==============================] - 1s 36ms/step - loss: 2.1952e-05 - accuracy: 1.0000 - val_loss: 2.3411e-07 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 70/100
# 22/23 [===========================>..] - ETA: 0s - loss: 3.2726e-05 - accuracy: 1.0000
# Epoch 70: val_loss did not improve from 0.00000
# 23/23 [==============================] - 1s 36ms/step - loss: 5.0419e-05 - accuracy: 1.0000 - val_loss: 2.2406e-07 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 71/100
# 21/23 [==========================>...] - ETA: 0s - loss: 1.8451e-05 - accuracy: 1.0000
# Epoch 71: val_loss did not improve from 0.00000
# 23/23 [==============================] - 1s 36ms/step - loss: 1.7523e-05 - accuracy: 1.0000 - val_loss: 2.2262e-07 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 72/100
# 21/23 [==========================>...] - ETA: 0s - loss: 5.9977e-05 - accuracy: 1.0000
# Epoch 72: val_loss did not improve from 0.00000
# 23/23 [==============================] - 1s 37ms/step - loss: 5.7106e-05 - accuracy: 1.0000 - val_loss: 2.2406e-07 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 73/100
# 23/23 [==============================] - ETA: 0s - loss: 1.8866e-05 - accuracy: 1.0000
# Epoch 73: val_loss did not improve from 0.00000
# 23/23 [==============================] - 1s 37ms/step - loss: 1.8866e-05 - accuracy: 1.0000 - val_loss: 2.2693e-07 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 74/100
# 23/23 [==============================] - ETA: 0s - loss: 1.5174e-05 - accuracy: 1.0000
# Epoch 74: val_loss did not improve from 0.00000
# 23/23 [==============================] - 1s 37ms/step - loss: 1.5174e-05 - accuracy: 1.0000 - val_loss: 2.2693e-07 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 75/100
# 22/23 [===========================>..] - ETA: 0s - loss: 4.5101e-05 - accuracy: 1.0000
# Epoch 75: val_loss did not improve from 0.00000
# 23/23 [==============================] - 1s 36ms/step - loss: 4.3207e-05 - accuracy: 1.0000 - val_loss: 2.2693e-07 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 76/100
# 22/23 [===========================>..] - ETA: 0s - loss: 8.7811e-06 - accuracy: 1.0000
# Epoch 76: val_loss did not improve from 0.00000
# 23/23 [==============================] - 1s 37ms/step - loss: 1.0451e-05 - accuracy: 1.0000 - val_loss: 2.2980e-07 - val_accuracy: 1.0000 - lr: 1.0000e-05

# %% [markdown]
# ### 3.11 Evaluating the Model

# %%
plt.figure(1)
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.legend(["Training", "Validation"])
plt.title("Loss")
plt.xlabel("Epoch")

plt.figure(2)
plt.plot(history.history["accuracy"])
plt.plot(history.history["val_accuracy"])
plt.legend(["Training", "Validation"])
plt.title("Accuracy")
plt.xlabel("Epoch")
plt.show()

score = model.evaluate(X_test, y_test, verbose=0)
print("Test Score:", score[0])
print("Test Accuracy:", score[1])
# Out:
# Test Score: 2.9231878215796314e-06
# Test Accuracy: 1.0

# %% [markdown]
# Confusion Matrix

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in d:\kuliah\d4 - pens\proyek akhir\project\program\garbage\.venv\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in d:\kuliah\d4 - pens\proyek akhir\project\program\garbage\.venv\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in d:\kuliah\d4 - pens\proyek akhir\project\program\garbage\.venv\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in d:\kuliah\d4 - pens\proyek akhir\project\program\garbage\.venv\lib\site-packages (from seaborn) (3.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in d:\kuliah\d4 - pens\proyek akhir\project\program\garbage\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in d:\kuliah\d4 - pens\proyek akhir\project\program\garbage\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\kuliah\d4 - pens\proyek akhir\project\program\garbage\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.52.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\kuliah\d4 - pens\proyek akhir\project\program\garbage\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in d:\kuliah\d4 - pens\proyek akhir\project\program\garbage\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.0)
# Requirement already satisfied: pillow>=8 in d:\kuliah\d4 - pens\proyek akhir\project\program\garbage\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\kuliah\d4 - pens\proyek akhir\project\program\garbage\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in d:\kuliah\d4 - pens\proyek akhir\project\program\garbage\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in d:\kuliah\d4 - pens\proyek akhir\project\program\garbage\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (6.4.0)
# Requirement already satisfied: pytz>=2020.1 in d:\kuliah\d4 - pens\proyek akhir\project\program\garbage\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\kuliah\d4 - pens\proyek akhir\project\program\garbage\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: zipp>=3.1.0 in d:\kuliah\d4 - pens\proyek akhir\project\program\garbage\.venv\lib\site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.4->seaborn) (3.19.0)
# Requirement already satisfied: six>=1.5 in d:\kuliah\d4 - pens\proyek akhir\project\program\garbage\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)

# %%
# !pip list
# Out:
# Package                      Version
# ---------------------------- -------------------
# absl-py                      2.1.0
# asttokens                    2.4.1
# astunparse                   1.6.3
# cachetools                   5.3.3
# certifi                      2024.2.2
# charset-normalizer           3.3.2
# colorama                     0.4.6
# comm                         0.2.2
# contourpy                    1.2.1
# cycler                       0.12.1
# debugpy                      1.8.1
# decorator                    5.1.1
# exceptiongroup               1.2.1
# executing                    2.0.1
# filelock                     3.13.1
# flatbuffers                  24.3.25
# fonttools                    4.52.4
# fsspec                       2024.2.0
# gast                         0.5.4
# google-auth                  2.29.0
# google-auth-oauthlib         0.4.6
# google-pasta                 0.2.0
# grpcio                       1.64.0
# h5py                         3.11.0
# idna                         3.7
# importlib_metadata           7.1.0
# importlib_resources          6.4.0
# intel-openmp                 2021.4.0
# ipykernel                    6.29.4
# ipython                      8.18.1
# jedi                         0.19.1
# Jinja2                       3.1.3
# joblib                       1.4.2
# jupyter_client               8.6.2
# jupyter_core                 5.7.2
# keras                        2.8.0
# Keras-Preprocessing          1.1.2
# kiwisolver                   1.4.5
# libclang                     18.1.1
# Markdown                     3.6
# MarkupSafe                   2.1.5
# matplotlib                   3.9.0
# matplotlib-inline            0.1.7
# mkl                          2021.4.0
# mpmath                       1.3.0
# nest-asyncio                 1.6.0
# networkx                     3.2.1
# numpy                        1.26.4
# oauthlib                     3.2.2
# opencv-python                4.9.0.80
# opt-einsum                   3.3.0
# packaging                    24.0
# pandas                       2.2.2
# parso                        0.8.4
# pillow                       10.3.0
# pip                          24.0
# platformdirs                 4.2.2
# prompt_toolkit               3.0.45
# protobuf                     3.20.0
# psutil                       5.9.8
# pure-eval                    0.2.2
# pyasn1                       0.6.0
# pyasn1_modules               0.4.0
# Pygments                     2.18.0
# pyparsing                    3.1.2
# python-dateutil              2.9.0.post0
# pytz                         2024.1
# pywin32                      306
# pyzmq                        26.0.3
# requests                     2.32.2
# requests-oauthlib            2.0.0
# rsa                          4.9
# scikit-learn                 1.5.0
# scipy                        1.13.1
# seaborn                      0.13.2
# setuptools                   58.1.0
# six                          1.16.0
# stack-data                   0.6.3
# sympy                        1.12
# tbb                          2021.11.0
# tensorboard                  2.8.0
# tensorboard-data-server      0.6.1
# tensorboard-plugin-wit       1.8.1
# tensorflow                   2.8.0
# tensorflow-gpu               2.8.0
# tensorflow-io-gcs-filesystem 0.31.0
# termcolor                    2.4.0
# tf-estimator-nightly         2.8.0.dev2021122109
# threadpoolctl                3.5.0
# torch                        2.3.0+cu118
# torchaudio                   2.3.0+cu118
# torchvision                  0.18.0+cu118
# tornado                      6.4
# traitlets                    5.14.3
# typing_extensions            4.12.0
# tzdata                       2024.1
# urllib3                      2.2.1
# wcwidth                      0.2.13
# Werkzeug                     3.0.3
# wheel                        0.43.0
# wrapt                        1.16.0
# zipp                         3.19.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report

# %%
# Predict on Test Set
y_test_pred = model.predict(X_test)
y_test_pred_classes = np.argmax(y_test_pred, axis=1)
y_test_true_classes = np.argmax(y_test, axis=1)


# Confusion Matrix
mat = confusion_matrix(y_test_true_classes, y_test_pred_classes)


# Class labels
def getClassName(class_no):
    classes = [
        "Not Littering",
        "Littering",
    ]
    return classes[class_no] if 0 <= class_no < len(classes) else "Unknown"


class_labels = [getClassName(i) for i in range(no_of_classes)]

sns.set()
plt.figure(figsize=(10, 8))
sns.heatmap(
    mat,
    square=True,
    annot=True,
    fmt="d",
    cbar=True,
    cmap="Blues",
    xticklabels=class_labels,
    yticklabels=class_labels,
)
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("Actual Label")
plt.show()

# %% [markdown]
# Classification Report

# %%
# Classification Report
report = classification_report(
    y_test_true_classes, y_test_pred_classes, target_names=class_labels
)
print(report)
# Out:
#                precision    recall  f1-score   support
#
# Not Littering       1.00      1.00      1.00        98
#     Littering       1.00      1.00      1.00       109
#
#      accuracy                           1.00       207
#     macro avg       1.00      1.00      1.00       207
#  weighted avg       1.00      1.00      1.00       207

# %% [markdown]
# Display Images with Predictions

# %%
# Display Images with Predictions
plt.figure(figsize=(10, 10))
indices = np.random.choice(len(X_test), 9, replace=False)
for i, index in enumerate(indices):
    ax = plt.subplot(3, 3, i + 1)
    img = (
        X_test[index].reshape(
            image_dimensions[0], image_dimensions[1], image_dimensions[2]
        )
        * 255.0
    )
    plt.imshow(img.astype("uint8"))
    plt.title(
        f"Predicted: {class_labels[y_test_pred_classes[index]]}\nActual: {class_labels[y_test_true_classes[index]]}"
    )
    plt.axis("off")
plt.show()

# %% [markdown]
# Prediction Function

# %%
def predict(path):
    imageShow = tf.keras.preprocessing.image.load_img(path, target_size=(500, 500))
    image = tf.keras.preprocessing.image.load_img(path, target_size=(72, 128))
    image_array = tf.keras.preprocessing.image.img_to_array(image)
    image_array = tf.expand_dims(image_array, axis=0)  # Create batch axis
    image_array /= 255.0

    predictions = model.predict(image_array)
    for i, label in enumerate(class_labels):
        print(f"{label}: {predictions[0][i]}")
    score = predictions[0]
    predicted_class = np.argmax(score)
    prediction = class_labels[predicted_class]

    plt.imshow(imageShow)
    plt.title(prediction)
    plt.axis("off")
    plt.show()

# %%
predict("images/0/20240109_123839_tp00078 4_92.jpg")
predict("images/1/20240109_123839_tp00078 4_135.jpg")
# Out:
# Not Littering: 1.0
# Littering: 6.305373584369889e-11
# Not Littering: 1.0
# Littering: 1.6385268597395397e-37
